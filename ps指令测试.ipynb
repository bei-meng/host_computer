# %%
import time
import json
import os
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import BoundaryNorm
from matplotlib.colors import Normalize
from PIL import Image
import os
import sys
sys.path.append(os.path.dirname(os.getcwd()))
from pc import PS
from modules import ADC,DAC,CHIP
from command import CMD,CmdData,Packet
from command.singleCmdInfo import *

from util import plot_v_cond,plot_cond,show_crossbar,DataLoader

from network.layer import Layer

# %%
chip=CHIP(PS(host="192.168.1.10", port = 7, debug=1),init=True)
chip.set_device_cfg(deviceType=0)
chip.adc.set_gap(adc_cs_gap=100,adc_first_gap=20,adc_last_gap=20)
chip.adc.set_gain_resistor(big_resistance=22e-3,small_resistance=200)
chip.clk_manager.set_cyc(delay1=20,delay2=50,delay3=50)
chip.add_compiler("./compiler/code/")
# Out:
# 完整字节码: 55aa010900000fff
# 完整字节码: 55aa010100000080
# 完整字节码: 55aa010100000100
# 完整字节码: 55aa010b00000001
# 完整字节码: 55aa010d00000001
# 完整字节码: 55aa010e00000001
# 模式: 1
# 	帧头:               	字节码: 55 aa 01
# 	指令: flt           	字节码: 09 00 00 0f ff
# 模式: 1
# 	帧头:               	字节码: 55 aa 01
# 	指令: fast_command_1	字节码: 01 00 00 00 80
# 模式: 1
# 	帧头:               	字节码: 55 aa 01
# 	指令: fast_command_1	字节码: 01 00 00 01 00
# 模式: 1
# 	帧头:               	字节码: 55 aa 01
# 	指令: cim_reset     	字节码: 0b 00 00 00 01
# 模式: 1
# 	帧头:               	字节码: 55 aa 01
# 	指令: cim_ss        	字节码: 0d 00 00 00 01
# 模式: 1
# 	帧头:               	字节码: 55 aa 01
# 	指令: ser_para_sel  	字节码: 0e 00 00 00 01
#
# Failed to send message:
# 完整字节码: 55aa01030000a200
# 完整字节码: 55aa01040000a200
# 完整字节码: 55aa01050000a200
# 完整字节码: 55aa01060000a200
# 完整字节码: 55aa01320000a200
# 完整字节码: 55aa01330000a200
# 完整字节码: 55aa01340000a200
# 完整字节码: 55aa01350000a200
# 完整字节码: 55aa0101000f001e
# 模式: 1
# 	帧头:               	字节码: 55 aa 01
# 	指令: adc0_in       	字节码: 03 00 00 a2 00
# 模式: 1
# 	帧头:               	字节码: 55 aa 01
# 	指令: adc1_in       	字节码: 04 00 00 a2 00
# 模式: 1
# 	帧头:               	字节码: 55 aa 01
# 	指令: adc2_in       	字节码: 05 00 00 a2 00
# 模式: 1
# 	帧头:               	字节码: 55 aa 01
# 	指令: adc3_in       	字节码: 06 00 00 a2 00
# 模式: 1
# 	帧头:               	字节码: 55 aa 01
# 	指令: adc4_in       	字节码: 32 00 00 a2 00
# 模式: 1
# 	帧头:               	字节码: 55 aa 01
# 	指令: adc5_in       	字节码: 33 00 00 a2 00
# 模式: 1
# 	帧头:               	字节码: 55 aa 01
# 	指令: adc6_in       	字节码: 34 00 00 a2 00
# 模式: 1
# 	帧头:               	字节码: 55 aa 01
# 	指令: adc7_in       	字节码: 35 00 00 a2 00
# 模式: 1
# 	帧头:               	字节码: 55 aa 01
# 	指令: fast_command_1	字节码: 01 00 0f 00 1e
#
# Failed to send message:
# 完整字节码: 55aa01190000000a
# 完整字节码: 55aa011700000064
# 完整字节码: 55aa011a0000000a
# 模式: 1
# 	帧头:              	字节码: 55 aa 01
# 	指令: adc_first_gap	字节码: 19 00 00 00 0a
# 模式: 1
# 	帧头:              	字节码: 55 aa 01
# 	指令: adc_cs_gap   	字节码: 17 00 00 00 64
# 模式: 1
# 	帧头:              	字节码: 55 aa 01
# 	指令: adc_last_gap 	字节码: 1a 00 00 00 0a
#
# Failed to send message:
# 完整字节码: 55aa010200020000
# 完整字节码: 55aa010100000001
# 完整字节码: 55aa0102000400ff
# 完整字节码: 55aa010100000001
# 完整字节码: 55aa010201020000
# 完整字节码: 55aa010100000001
# 完整字节码: 55aa0102010400ff
# 完整字节码: 55aa010100000001
# 模式: 1
# 	帧头:               	字节码: 55 aa 01
# 	指令: dac_in        	字节码: 02 00 02 00 00
# 模式: 1
# 	帧头:               	字节码: 55 aa 01
# 	指令: fast_command_1	字节码: 01 00 00 00 01
# 模式: 1
# 	帧头:               	字节码: 55 aa 01
# 	指令: dac_in        	字节码: 02 00 04 00 ff
# 模式: 1
# 	帧头:               	字节码: 55 aa 01
# 	指令: fast_command_1	字节码: 01 00 00 00 01
# 模式: 1
# 	帧头:               	字节码: 55 aa 01
# 	指令: dac_in        	字节码: 02 01 02 00 00
# 模式: 1
# 	帧头:               	字节码: 55 aa 01
# 	指令: fast_command_1	字节码: 01 00 00 00 01
# 模式: 1
# 	帧头:               	字节码: 55 aa 01
# 	指令: dac_in        	字节码: 02 01 04 00 ff
# 模式: 1
# 	帧头:               	字节码: 55 aa 01
# 	指令: fast_command_1	字节码: 01 00 00 00 01
#
# Failed to send message:
# 完整字节码: 55aa01120000ffff
# 模式: 1
# 	帧头:        	字节码: 55 aa 01
# 	指令: dac_ctr	字节码: 12 00 00 ff ff
#
# Failed to send message:
# 完整字节码: 55aa011e00000014
# 完整字节码: 55aa011f00000014
# 完整字节码: 55aa012000000014
# 完整字节码: 55aa012100000014
# 完整字节码: 55aa012200000014
# 完整字节码: 55aa012300000014
# 完整字节码: 55aa012400000014
# 完整字节码: 55aa012500000014
# 完整字节码: 55aa012600000014
# 完整字节码: 55aa012700000014
# 完整字节码: 55aa012800000014
# 完整字节码: 55aa012900000014
# 完整字节码: 55aa012a00000064
# 模式: 1
# 	帧头:                               	字节码: 55 aa 01
# 	指令: op_bank_cfg_done_delay_cyc    	字节码: 1e 00 00 00 14
# 模式: 1
# 	帧头:                               	字节码: 55 aa 01
# 	指令: op_cim_data_cfg_done_delay_cyc	字节码: 1f 00 00 00 14
# 模式: 1
# 	帧头:                               	字节码: 55 aa 01
# 	指令: reg_clk_done_delay_cyc        	字节码: 20 00 00 00 14
# 模式: 1
# 	帧头:                               	字节码: 55 aa 01
# 	指令: latch_clk_done_delay_cyc      	字节码: 21 00 00 00 14
# 模式: 1
# 	帧头:                               	字节码: 55 aa 01
# 	指令: op_adc_avrg_done_delay_cyc    	字节码: 22 00 00 00 14
# 模式: 1
# 	帧头:                               	字节码: 55 aa 01
# 	指令: op_dac_cfg_done_delay_cyc     	字节码: 23 00 00 00 14
# 模式: 1
# 	帧头:                               	字节码: 55 aa 01
# 	指令: op_row_pulse_done_delay_cyc   	字节码: 24 00 00 00 14
# 模式: 1
# 	帧头:                               	字节码: 55 aa 01
# 	指令: op_col_pulse_done_delay_cyc   	字节码: 25 00 00 00 14
# 模式: 1
# 	帧头:                               	字节码: 55 aa 01
# 	指令: op_cim_rstn_done_delay_cyc    	字节码: 26 00 00 00 14
# 模式: 1
# 	帧头:                               	字节码: 55 aa 01
# 	指令: cim_rstn_cyc                  	字节码: 27 00 00 00 14
# 模式: 1
# 	帧头:                               	字节码: 55 aa 01
# 	指令: latch_clk_cyc                 	字节码: 28 00 00 00 14
# 模式: 1
# 	帧头:                               	字节码: 55 aa 01
# 	指令: reg_clk_cyc                   	字节码: 29 00 00 00 14
# 模式: 1
# 	帧头:                               	字节码: 55 aa 01
# 	指令: latch_cyc                     	字节码: 2a 00 00 00 64
#
# Failed to send message:
# 完整字节码: 55aa010700000000
# 模式: 1
# 	帧头:           	字节码: 55 aa 01
# 	指令: device_cfg	字节码: 07 00 00 00 00
#
# Failed to send message:
# 完整字节码: 55aa011900000014
# 完整字节码: 55aa011700000064
# 完整字节码: 55aa011a00000014
# 模式: 1
# 	帧头:              	字节码: 55 aa 01
# 	指令: adc_first_gap	字节码: 19 00 00 00 14
# 模式: 1
# 	帧头:              	字节码: 55 aa 01
# 	指令: adc_cs_gap   	字节码: 17 00 00 00 64
# 模式: 1
# 	帧头:              	字节码: 55 aa 01
# 	指令: adc_last_gap 	字节码: 1a 00 00 00 14
#
# Failed to send message:
# 完整字节码: 55aa011e00000014
# 完整字节码: 55aa011f00000014
# 完整字节码: 55aa012000000014
# 完整字节码: 55aa012100000014
# 完整字节码: 55aa012200000014
# 完整字节码: 55aa012300000014
# 完整字节码: 55aa012400000014
# 完整字节码: 55aa012500000014
# 完整字节码: 55aa012600000014
# 完整字节码: 55aa012700000032
# 完整字节码: 55aa012800000032
# 完整字节码: 55aa012900000032
# 完整字节码: 55aa012a00000032
# 模式: 1
# 	帧头:                               	字节码: 55 aa 01
# 	指令: op_bank_cfg_done_delay_cyc    	字节码: 1e 00 00 00 14
# 模式: 1
# 	帧头:                               	字节码: 55 aa 01
# 	指令: op_cim_data_cfg_done_delay_cyc	字节码: 1f 00 00 00 14
# 模式: 1
# 	帧头:                               	字节码: 55 aa 01
# 	指令: reg_clk_done_delay_cyc        	字节码: 20 00 00 00 14
# 模式: 1
# 	帧头:                               	字节码: 55 aa 01
# 	指令: latch_clk_done_delay_cyc      	字节码: 21 00 00 00 14
# 模式: 1
# 	帧头:                               	字节码: 55 aa 01
# 	指令: op_adc_avrg_done_delay_cyc    	字节码: 22 00 00 00 14
# 模式: 1
# 	帧头:                               	字节码: 55 aa 01
# 	指令: op_dac_cfg_done_delay_cyc     	字节码: 23 00 00 00 14
# 模式: 1
# 	帧头:                               	字节码: 55 aa 01
# 	指令: op_row_pulse_done_delay_cyc   	字节码: 24 00 00 00 14
# 模式: 1
# 	帧头:                               	字节码: 55 aa 01
# 	指令: op_col_pulse_done_delay_cyc   	字节码: 25 00 00 00 14
# 模式: 1
# 	帧头:                               	字节码: 55 aa 01
# 	指令: op_cim_rstn_done_delay_cyc    	字节码: 26 00 00 00 14
# 模式: 1
# 	帧头:                               	字节码: 55 aa 01
# 	指令: cim_rstn_cyc                  	字节码: 27 00 00 00 32
# 模式: 1
# 	帧头:                               	字节码: 55 aa 01
# 	指令: latch_clk_cyc                 	字节码: 28 00 00 00 32
# 模式: 1
# 	帧头:                               	字节码: 55 aa 01
# 	指令: reg_clk_cyc                   	字节码: 29 00 00 00 32
# 模式: 1
# 	帧头:                               	字节码: 55 aa 01
# 	指令: latch_cyc                     	字节码: 2a 00 00 00 32
#
# Failed to send message:
# 正在编译文件:  ./compiler/code/read_point3_from_col.txt
# 正在编译文件:  ./compiler/code/read_point3_from_row.txt
# 正在编译文件:  ./compiler/code/row_read_point3.txt
# 正在编译文件:  ./compiler/code/set_reset.txt
# 正在编译文件:  ./compiler/code/write_verify.txt
# 指令set_dac未实现
# 指令set_dac未实现
# 正在编译文件:  ./compiler/code/汇编测试代码.txt
# 正在编译文件:  ./compiler/code/读任意大小的块-汇编代码示例.txt
# 正在编译文件:  ./compiler/code/读单点测试.txt

# %%
ps_ddr_pos_start = 0
crossbar = np.ones((256,256))

ps_ddr_pos = ps_ddr_pos_start
for i in range(1):
    ps_ddr_pos=chip.write5(crossbar=crossbar,row_index=None,col_index=None,write_voltage=1,tg=5,pulse_width=1e-6,set_device=True,split_type=2,row_type=0,col_type=0,ps_ddr_pos=ps_ddr_pos)

# 先finsh
ins_data = [CMD(PS_START_FINSH,command_data=CmdData(1)),CMD(PS_DDR_ADDR,command_data=CmdData(ps_ddr_pos_start))]
ps_ddr_pos=chip.send_ps_ddr5(ddr_data=ins_data,mode=11,ps_ddr_pos=ps_ddr_pos)
# 再start
ins_data = [CMD(PS_START_FINSH,command_data=CmdData(0)),CMD(PS_DDR_ADDR,command_data=CmdData(ps_ddr_pos_start))]
ps_ddr_pos=chip.send_ps_ddr5(ddr_data=ins_data,mode=11,ps_ddr_pos=ps_ddr_pos)
# Out:
# 完整字节码: 55aa090000000000000003190100001a0000001b010000
# 模式: 9
# 	帧头:               	字节码: 55 aa 09
# 	指令: ps_ddr_addr   	字节码: 00 00 00 00
# 	指令: ps_data_length	字节码: 00 00 00 03
# 	指令: pl_row_ctrli  	字节码: 19 01 00 00
# 	指令: pl_col_ctrli  	字节码: 1a 00 00 00
# 	指令: pl_row_col_swi	字节码: 1b 01 00 00
#
# Failed to send message:
# 完整字节码: 55aa0a000000101b00000064
# 模式: 10
# 	帧头:            	字节码: 55 aa 0a
# 	指令: ps_ddr_addr	字节码: 00 00 00 10
# 	指令: pulse_cyc  	字节码: 1b 00 00 00 64
#
# Failed to send message:
# 完整字节码: 
# 模式: 8
# 	帧头:               	字节码: 55 aa 08
# 	指令: ps_ddr_addr   	字节码: 00 00 00 18
# 	指令: ps_data_length	字节码: 00 00 00 22
# 	指令: pl_data       	字节码: 00 00 00 00
# 	指令: pl_data       	字节码: ff ff ff ff
# 	指令: pl_data       	字节码: 00 00 00 01
# 	指令: pl_data       	字节码: 00 00 00 02
# 	指令: pl_data       	字节码: 00 00 00 04
# 	指令: pl_data       	字节码: 00 00 00 08
# 	指令: pl_data       	字节码: 00 00 00 10
# 	指令: pl_data       	字节码: 00 00 00 20
# 	指令: pl_data       	字节码: 00 00 00 40
# 	指令: pl_data       	字节码: 00 00 00 80
# 	指令: pl_data       	字节码: 00 00 01 00
# 	指令: pl_data       	字节码: 00 00 02 00
# 	指令: pl_data       	字节码: 00 00 04 00
# 	指令: pl_data       	字节码: 00 00 08 00
# 	指令: pl_data       	字节码: 00 00 10 00
# 	指令: pl_data       	字节码: 00 00 20 00
# 	指令: pl_data       	字节码: 00 00 40 00
# 	指令: pl_data       	字节码: 00 00 80 00
# 	指令: pl_data       	字节码: 00 01 00 00
# 	指令: pl_data       	字节码: 00 02 00 00
# 	指令: pl_data       	字节码: 00 04 00 00
# 	指令: pl_data       	字节码: 00 08 00 00
# 	指令: pl_data       	字节码: 00 10 00 00
# 	指令: pl_data       	字节码: 00 20 00 00
# 	指令: pl_data       	字节码: 00 40 00 00
# 	指令: pl_data       	字节码: 00 80 00 00
# 	指令: pl_data       	字节码: 01 00 00 00
# 	指令: pl_data       	字节码: 02 00 00 00
# 	指令: pl_data       	字节码: 04 00 00 00
# 	指令: pl_data       	字节码: 08 00 00 00
# 	指令: pl_data       	字节码: 10 00 00 00
# 	指令: pl_data       	字节码: 20 00 00 00
# 	指令: pl_data       	字节码: 40 00 00 00
# 	指令: pl_data       	字节码: 80 00 00 00
#
# Failed to send message:
# 完整字节码: ...
# 模式: 9
# 	帧头:                   	字节码: 55 aa 09
# 	指令: ps_ddr_addr       	字节码: 00 00 00 48
# 	指令: ps_data_length    	字节码: 00 00 01 17
# 	指令: pl_dac_v          	字节码: 03 08 33 30
# 	指令: pl_dac_v          	字节码: 03 06 ff f0
# 	指令: pl_row_bank       	字节码: 01 00 ff 00
# 	指令: pl_row_bank       	字节码: 01 00 01 01
# 	指令: pl_row_bank       	字节码: 01 00 02 01
# 	指令: pl_row_bank       	字节码: 01 00 04 01
# 	指令: pl_row_bank       	字节码: 01 00 08 01
# 	指令: pl_row_bank       	字节码: 01 00 10 01
# 	指令: pl_row_bank       	字节码: 01 00 20 01
# 	指令: pl_row_bank       	字节码: 01 00 40 01
# 	指令: pl_row_bank       	字节码: 01 00 80 01
# 	指令: pl_col_bank       	字节码: 02 00 ff 00
# 	指令: pl_col_bank       	字节码: 02 00 01 02
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 01 03
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 01 04
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 01 05
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 01 06
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 01 07
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 01 08
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 01 09
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 01 0a
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 01 0b
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 01 0c
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 01 0d
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 01 0e
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 01 0f
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 01 10
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 01 11
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 01 12
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 01 13
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 01 14
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 01 15
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 01 16
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 01 17
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 01 18
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 01 19
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 01 1a
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 01 1b
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 01 1c
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 01 1d
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 01 1e
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 01 1f
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 01 20
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 01 21
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 ff 00
# 	指令: pl_col_bank       	字节码: 02 00 02 02
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 02 03
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 02 04
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 02 05
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 02 06
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 02 07
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 02 08
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 02 09
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 02 0a
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 02 0b
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 02 0c
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 02 0d
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 02 0e
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 02 0f
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 02 10
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 02 11
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 02 12
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 02 13
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 02 14
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 02 15
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 02 16
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 02 17
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 02 18
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 02 19
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 02 1a
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 02 1b
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 02 1c
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 02 1d
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 02 1e
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 02 1f
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 02 20
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 02 21
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 ff 00
# 	指令: pl_col_bank       	字节码: 02 00 04 02
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 04 03
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 04 04
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 04 05
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 04 06
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 04 07
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 04 08
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 04 09
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 04 0a
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 04 0b
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 04 0c
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 04 0d
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 04 0e
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 04 0f
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 04 10
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 04 11
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 04 12
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 04 13
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 04 14
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 04 15
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 04 16
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 04 17
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 04 18
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 04 19
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 04 1a
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 04 1b
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 04 1c
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 04 1d
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 04 1e
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 04 1f
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 04 20
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 04 21
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 ff 00
# 	指令: pl_col_bank       	字节码: 02 00 08 02
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 08 03
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 08 04
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 08 05
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 08 06
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 08 07
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 08 08
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 08 09
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 08 0a
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 08 0b
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 08 0c
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 08 0d
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 08 0e
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 08 0f
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 08 10
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 08 11
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 08 12
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 08 13
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 08 14
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 08 15
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 08 16
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 08 17
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 08 18
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 08 19
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 08 1a
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 08 1b
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 08 1c
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 08 1d
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 08 1e
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 08 1f
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 08 20
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 08 21
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 ff 00
# 	指令: pl_col_bank       	字节码: 02 00 10 02
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 10 03
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 10 04
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_exit           	字节码: 0b 00 00 00
#
# Failed to send message:
# 完整字节码: ...
# 模式: 9
# 	帧头:                   	字节码: 55 aa 09
# 	指令: ps_ddr_addr       	字节码: 00 00 01 68
# 	指令: ps_data_length    	字节码: 00 00 00 fe
# 	指令: pl_col_bank       	字节码: 02 00 10 05
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 10 06
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 10 07
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 10 08
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 10 09
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 10 0a
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 10 0b
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 10 0c
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 10 0d
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 10 0e
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 10 0f
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 10 10
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 10 11
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 10 12
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 10 13
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 10 14
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 10 15
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 10 16
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 10 17
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 10 18
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 10 19
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 10 1a
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 10 1b
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 10 1c
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 10 1d
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 10 1e
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 10 1f
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 10 20
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 10 21
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 ff 00
# 	指令: pl_col_bank       	字节码: 02 00 20 02
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 20 03
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 20 04
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 20 05
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 20 06
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 20 07
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 20 08
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 20 09
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 20 0a
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 20 0b
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 20 0c
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 20 0d
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 20 0e
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 20 0f
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 20 10
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 20 11
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 20 12
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 20 13
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 20 14
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 20 15
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 20 16
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 20 17
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 20 18
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 20 19
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 20 1a
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 20 1b
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 20 1c
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 20 1d
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 20 1e
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 20 1f
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 20 20
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 20 21
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 ff 00
# 	指令: pl_col_bank       	字节码: 02 00 40 02
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 40 03
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 40 04
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 40 05
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 40 06
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 40 07
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 40 08
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 40 09
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 40 0a
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 40 0b
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 40 0c
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 40 0d
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 40 0e
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 40 0f
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 40 10
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 40 11
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 40 12
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 40 13
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 40 14
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 40 15
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 40 16
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 40 17
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 40 18
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 40 19
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 40 1a
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 40 1b
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 40 1c
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 40 1d
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 40 1e
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 40 1f
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 40 20
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 40 21
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 ff 00
# 	指令: pl_col_bank       	字节码: 02 00 80 02
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 80 03
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 80 04
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 80 05
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 80 06
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 80 07
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 80 08
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 80 09
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 80 0a
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 80 0b
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 80 0c
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 80 0d
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 80 0e
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 80 0f
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 80 10
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 80 11
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 80 12
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 80 13
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 80 14
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 80 15
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 80 16
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 80 17
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 80 18
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 80 19
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 80 1a
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 80 1b
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 80 1c
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 80 1d
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 80 1e
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 80 1f
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 80 20
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_col_bank       	字节码: 02 00 80 21
# 	指令: pl_write_row_pulse	字节码: 06 00 00 00
# 	指令: pl_exit           	字节码: 0b 00 00 00
#
# Failed to send message:
# 完整字节码: 55aa0b000002700100000000
# 模式: 11
# 	帧头:               	字节码: 55 aa 0b
# 	指令: ps_ddr_addr   	字节码: 00 00 02 70
# 	指令: ps_start_finsh	字节码: 01
# 	指令: ps_ddr_addr   	字节码: 00 00 00 00
#
# Failed to send message:
# 完整字节码: 55aa0b000002780000000000
# 模式: 11
# 	帧头:               	字节码: 55 aa 0b
# 	指令: ps_ddr_addr   	字节码: 00 00 02 78
# 	指令: ps_start_finsh	字节码: 00
# 	指令: ps_ddr_addr   	字节码: 00 00 00 00
#
# Failed to send message:

# %%
import time
import os
import numpy as np
import sys
sys.path.append(os.path.dirname(os.getcwd()))
from modules import CHIP

# %%
chip=CHIP(local_ip="192.168.1.15",remote_ip="192.168.1.12",remote_port=7,debug=1,init=True)
chip.set_device_cfg(deviceType=1,IsNew32=True,IsRERAM512=False)
chip.adc.set_gap(adc_cs_gap=100,adc_first_gap=20,adc_last_gap=20)
chip.adc.set_gain_resistor(big_resistance=22e-3,small_resistance=200)
chip.clk_manager.set_cyc(delay1=10,delay2=10,delay3=50)
chip.add_compiler("./compiler/code/")
# Out:
# Failed to connect: [WinError 10049] 在其上下文中，该请求的地址无效。
# 完整字节码: 55aa010900000fff
# 完整字节码: 55aa010100000080
# 完整字节码: 55aa010100000100
# 完整字节码: 55aa010d00000001
# 完整字节码: 55aa010e00000001
# 模式: 1
# 	帧头:               	字节码: 55 aa 01
# 	指令: flt           	字节码: 09 00 00 0f ff
# 模式: 1
# 	帧头:               	字节码: 55 aa 01
# 	指令: fast_command_1	字节码: 01 00 00 00 80
# 模式: 1
# 	帧头:               	字节码: 55 aa 01
# 	指令: fast_command_1	字节码: 01 00 00 01 00
# 模式: 1
# 	帧头:               	字节码: 55 aa 01
# 	指令: cim_ss        	字节码: 0d 00 00 00 01
# 模式: 1
# 	帧头:               	字节码: 55 aa 01
# 	指令: ser_para_sel  	字节码: 0e 00 00 00 01
#
# Failed to send message:
# 完整字节码: 55aa010b00000001
# 模式: 1
# 	帧头:          	字节码: 55 aa 01
# 	指令: cim_reset	字节码: 0b 00 00 00 01
#
# Failed to send message:
# 完整字节码: 55aa01030000a200
# 完整字节码: 55aa01040000a200
# 完整字节码: 55aa01050000a200
# 完整字节码: 55aa01060000a200
# 完整字节码: 55aa01320000a200
# 完整字节码: 55aa01330000a200
# 完整字节码: 55aa01340000a200
# 完整字节码: 55aa01350000a200
# 完整字节码: 55aa0101000f001e
# 模式: 1
# 	帧头:               	字节码: 55 aa 01
# 	指令: adc0_in       	字节码: 03 00 00 a2 00
# 模式: 1
# 	帧头:               	字节码: 55 aa 01
# 	指令: adc1_in       	字节码: 04 00 00 a2 00
# 模式: 1
# 	帧头:               	字节码: 55 aa 01
# 	指令: adc2_in       	字节码: 05 00 00 a2 00
# 模式: 1
# 	帧头:               	字节码: 55 aa 01
# 	指令: adc3_in       	字节码: 06 00 00 a2 00
# 模式: 1
# 	帧头:               	字节码: 55 aa 01
# 	指令: adc4_in       	字节码: 32 00 00 a2 00
# 模式: 1
# 	帧头:               	字节码: 55 aa 01
# 	指令: adc5_in       	字节码: 33 00 00 a2 00
# 模式: 1
# 	帧头:               	字节码: 55 aa 01
# 	指令: adc6_in       	字节码: 34 00 00 a2 00
# 模式: 1
# 	帧头:               	字节码: 55 aa 01
# 	指令: adc7_in       	字节码: 35 00 00 a2 00
# 模式: 1
# 	帧头:               	字节码: 55 aa 01
# 	指令: fast_command_1	字节码: 01 00 0f 00 1e
#
# Failed to send message:
# 完整字节码: 55aa01190000000a
# 完整字节码: 55aa011700000064
# 完整字节码: 55aa011a0000000a
# 模式: 1
# 	帧头:              	字节码: 55 aa 01
# 	指令: adc_first_gap	字节码: 19 00 00 00 0a
# 模式: 1
# 	帧头:              	字节码: 55 aa 01
# 	指令: adc_cs_gap   	字节码: 17 00 00 00 64
# 模式: 1
# 	帧头:              	字节码: 55 aa 01
# 	指令: adc_last_gap 	字节码: 1a 00 00 00 0a
#
# Failed to send message:
# 完整字节码: 55aa010200020000
# 完整字节码: 55aa010100000001
# 完整字节码: 55aa0102000400ff
# 完整字节码: 55aa010100000001
# 完整字节码: 55aa010201020000
# 完整字节码: 55aa010100000001
# 完整字节码: 55aa0102010400ff
# 完整字节码: 55aa010100000001
# 模式: 1
# 	帧头:               	字节码: 55 aa 01
# 	指令: dac_in        	字节码: 02 00 02 00 00
# 模式: 1
# 	帧头:               	字节码: 55 aa 01
# 	指令: fast_command_1	字节码: 01 00 00 00 01
# 模式: 1
# 	帧头:               	字节码: 55 aa 01
# 	指令: dac_in        	字节码: 02 00 04 00 ff
# 模式: 1
# 	帧头:               	字节码: 55 aa 01
# 	指令: fast_command_1	字节码: 01 00 00 00 01
# 模式: 1
# 	帧头:               	字节码: 55 aa 01
# 	指令: dac_in        	字节码: 02 01 02 00 00
# 模式: 1
# 	帧头:               	字节码: 55 aa 01
# 	指令: fast_command_1	字节码: 01 00 00 00 01
# 模式: 1
# 	帧头:               	字节码: 55 aa 01
# 	指令: dac_in        	字节码: 02 01 04 00 ff
# 模式: 1
# 	帧头:               	字节码: 55 aa 01
# 	指令: fast_command_1	字节码: 01 00 00 00 01
#
# Failed to send message:
# 完整字节码: 55aa01120000ffff
# 模式: 1
# 	帧头:        	字节码: 55 aa 01
# 	指令: dac_ctr	字节码: 12 00 00 ff ff
#
# Failed to send message:
# 完整字节码: 55aa011e00000014
# 完整字节码: 55aa011f00000014
# 完整字节码: 55aa012000000014
# 完整字节码: 55aa012100000014
# 完整字节码: 55aa012200000014
# 完整字节码: 55aa012300000014
# 完整字节码: 55aa012400000014
# 完整字节码: 55aa012500000014
# 完整字节码: 55aa012600000014
# 完整字节码: 55aa012700000014
# 完整字节码: 55aa012800000014
# 完整字节码: 55aa012900000014
# 完整字节码: 55aa012a00000064
# 模式: 1
# 	帧头:                               	字节码: 55 aa 01
# 	指令: op_bank_cfg_done_delay_cyc    	字节码: 1e 00 00 00 14
# 模式: 1
# 	帧头:                               	字节码: 55 aa 01
# 	指令: op_cim_data_cfg_done_delay_cyc	字节码: 1f 00 00 00 14
# 模式: 1
# 	帧头:                               	字节码: 55 aa 01
# 	指令: reg_clk_done_delay_cyc        	字节码: 20 00 00 00 14
# 模式: 1
# 	帧头:                               	字节码: 55 aa 01
# 	指令: latch_clk_done_delay_cyc      	字节码: 21 00 00 00 14
# 模式: 1
# 	帧头:                               	字节码: 55 aa 01
# 	指令: op_adc_avrg_done_delay_cyc    	字节码: 22 00 00 00 14
# 模式: 1
# 	帧头:                               	字节码: 55 aa 01
# 	指令: op_dac_cfg_done_delay_cyc     	字节码: 23 00 00 00 14
# 模式: 1
# 	帧头:                               	字节码: 55 aa 01
# 	指令: op_row_pulse_done_delay_cyc   	字节码: 24 00 00 00 14
# 模式: 1
# 	帧头:                               	字节码: 55 aa 01
# 	指令: op_col_pulse_done_delay_cyc   	字节码: 25 00 00 00 14
# 模式: 1
# 	帧头:                               	字节码: 55 aa 01
# 	指令: op_cim_rstn_done_delay_cyc    	字节码: 26 00 00 00 14
# 模式: 1
# 	帧头:                               	字节码: 55 aa 01
# 	指令: cim_rstn_cyc                  	字节码: 27 00 00 00 14
# 模式: 1
# 	帧头:                               	字节码: 55 aa 01
# 	指令: latch_clk_cyc                 	字节码: 28 00 00 00 14
# 模式: 1
# 	帧头:                               	字节码: 55 aa 01
# 	指令: reg_clk_cyc                   	字节码: 29 00 00 00 14
# 模式: 1
# 	帧头:                               	字节码: 55 aa 01
# 	指令: latch_cyc                     	字节码: 2a 00 00 00 64
#
# Failed to send message:
# 完整字节码: 55aa010700000001
# 模式: 1
# 	帧头:           	字节码: 55 aa 01
# 	指令: device_cfg	字节码: 07 00 00 00 01
#
# Failed to send message:
# 完整字节码: 55aa011900000014
# 完整字节码: 55aa011700000064
# 完整字节码: 55aa011a00000014
# 模式: 1
# 	帧头:              	字节码: 55 aa 01
# 	指令: adc_first_gap	字节码: 19 00 00 00 14
# 模式: 1
# 	帧头:              	字节码: 55 aa 01
# 	指令: adc_cs_gap   	字节码: 17 00 00 00 64
# 模式: 1
# 	帧头:              	字节码: 55 aa 01
# 	指令: adc_last_gap 	字节码: 1a 00 00 00 14
#
# Failed to send message:
# 完整字节码: 55aa011e0000000a
# 完整字节码: 55aa011f0000000a
# 完整字节码: 55aa01200000000a
# 完整字节码: 55aa01210000000a
# 完整字节码: 55aa01220000000a
# 完整字节码: 55aa01230000000a
# 完整字节码: 55aa01240000000a
# 完整字节码: 55aa01250000000a
# 完整字节码: 55aa01260000000a
# 完整字节码: 55aa01270000000a
# 完整字节码: 55aa01280000000a
# 完整字节码: 55aa01290000000a
# 完整字节码: 55aa012a00000032
# 模式: 1
# 	帧头:                               	字节码: 55 aa 01
# 	指令: op_bank_cfg_done_delay_cyc    	字节码: 1e 00 00 00 0a
# 模式: 1
# 	帧头:                               	字节码: 55 aa 01
# 	指令: op_cim_data_cfg_done_delay_cyc	字节码: 1f 00 00 00 0a
# 模式: 1
# 	帧头:                               	字节码: 55 aa 01
# 	指令: reg_clk_done_delay_cyc        	字节码: 20 00 00 00 0a
# 模式: 1
# 	帧头:                               	字节码: 55 aa 01
# 	指令: latch_clk_done_delay_cyc      	字节码: 21 00 00 00 0a
# 模式: 1
# 	帧头:                               	字节码: 55 aa 01
# 	指令: op_adc_avrg_done_delay_cyc    	字节码: 22 00 00 00 0a
# 模式: 1
# 	帧头:                               	字节码: 55 aa 01
# 	指令: op_dac_cfg_done_delay_cyc     	字节码: 23 00 00 00 0a
# 模式: 1
# 	帧头:                               	字节码: 55 aa 01
# 	指令: op_row_pulse_done_delay_cyc   	字节码: 24 00 00 00 0a
# 模式: 1
# 	帧头:                               	字节码: 55 aa 01
# 	指令: op_col_pulse_done_delay_cyc   	字节码: 25 00 00 00 0a
# 模式: 1
# 	帧头:                               	字节码: 55 aa 01
# 	指令: op_cim_rstn_done_delay_cyc    	字节码: 26 00 00 00 0a
# 模式: 1
# 	帧头:                               	字节码: 55 aa 01
# 	指令: cim_rstn_cyc                  	字节码: 27 00 00 00 0a
# 模式: 1
# 	帧头:                               	字节码: 55 aa 01
# 	指令: latch_clk_cyc                 	字节码: 28 00 00 00 0a
# 模式: 1
# 	帧头:                               	字节码: 55 aa 01
# 	指令: reg_clk_cyc                   	字节码: 29 00 00 00 0a
# 模式: 1
# 	帧头:                               	字节码: 55 aa 01
# 	指令: latch_cyc                     	字节码: 2a 00 00 00 32
#
# Failed to send message:

# %%
chip.inference6(np.ones((128,16)),row_index=[0],col_index=[i for i in range(0,256,16)],read_voltage=0.1,tg=5,gain=1,sub_base=True,from_row=False,split_type=4,ps_ddr_pos=0)
# Out:
# 完整字节码: 55aa0a000000001d00000000
# 模式: 10
# 	帧头:            	字节码: 55 aa 0a
# 	指令: ps_ddr_addr	字节码: 00 00 00 00
# 	指令: ser_data   	字节码: 1d 00 00 00 00
#
# Failed to send message:
# 完整字节码: 55aa09000000010000001003000000030100000302000003030000030400000305000003060000030700000308000003090000030a0000030b0000190000001a0100001b0000000b000000
# 模式: 9
# 	帧头:               	字节码: 55 aa 09
# 	指令: ps_ddr_addr   	字节码: 00 00 00 01
# 	指令: ps_data_length	字节码: 00 00 00 10
# 	指令: pl_dac_v      	字节码: 03 00 00 00
# 	指令: pl_dac_v      	字节码: 03 01 00 00
# 	指令: pl_dac_v      	字节码: 03 02 00 00
# 	指令: pl_dac_v      	字节码: 03 03 00 00
# 	指令: pl_dac_v      	字节码: 03 04 00 00
# 	指令: pl_dac_v      	字节码: 03 05 00 00
# 	指令: pl_dac_v      	字节码: 03 06 00 00
# 	指令: pl_dac_v      	字节码: 03 07 00 00
# 	指令: pl_dac_v      	字节码: 03 08 00 00
# 	指令: pl_dac_v      	字节码: 03 09 00 00
# 	指令: pl_dac_v      	字节码: 03 0a 00 00
# 	指令: pl_dac_v      	字节码: 03 0b 00 00
# 	指令: pl_row_ctrli  	字节码: 19 00 00 00
# 	指令: pl_col_ctrli  	字节码: 1a 01 00 00
# 	指令: pl_row_col_swi	字节码: 1b 00 00 00
# 	指令: pl_exit       	字节码: 0b 00 00 00
#
# Failed to send message:
# 完整字节码: 55aa0a000000041000000001
# 模式: 10
# 	帧头:            	字节码: 55 aa 0a
# 	指令: ps_ddr_addr	字节码: 00 00 00 04
# 	指令: gain       	字节码: 10 00 00 00 01
#
# Failed to send message:
# 完整字节码: 55aa09000000050000000903000510030105100302051003030510030405100305051003060510030705100b000000
# 模式: 9
# 	帧头:               	字节码: 55 aa 09
# 	指令: ps_ddr_addr   	字节码: 00 00 00 05
# 	指令: ps_data_length	字节码: 00 00 00 09
# 	指令: pl_dac_v      	字节码: 03 00 05 10
# 	指令: pl_dac_v      	字节码: 03 01 05 10
# 	指令: pl_dac_v      	字节码: 03 02 05 10
# 	指令: pl_dac_v      	字节码: 03 03 05 10
# 	指令: pl_dac_v      	字节码: 03 04 05 10
# 	指令: pl_dac_v      	字节码: 03 05 05 10
# 	指令: pl_dac_v      	字节码: 03 06 05 10
# 	指令: pl_dac_v      	字节码: 03 07 05 10
# 	指令: pl_exit       	字节码: 0b 00 00 00
#
# Failed to send message:
# 完整字节码: ...
# 模式: 14
# 	帧头:               	字节码: 55 aa 0e
# 	指令: ps_ddr_addr   	字节码: 00 00 00 08
# 	指令: ps_data_length	字节码: 00 00 04 18
# 	指令: ps_image_data 	字节码: 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01 00 01
# 	指令: ps_image_data 	字节码: 03 00 05 10 03 01 05 10 03 02 05 10 03 03 05 10 03 04 05 10 03 05 05 10 03 06 05 10 03 07 05 10
# 	指令: ps_image_data 	字节码: 03 00 00 00 03 01 00 00 03 02 00 00 03 03 00 00 03 04 00 00 03 05 00 00 03 06 00 00 03 07 00 00
#
# Failed to send message:
# 完整字节码: 55aa0f0000008c0000000300000009000000800000000a000000010000008a00000010
# 模式: 15
# 	帧头:                  	字节码: 55 aa 0f
# 	指令: ps_ddr_addr      	字节码: 00 00 00 8c
# 	指令: pl_data          	字节码: 00 00 00 03
# 	指令: ps_ddr_addr      	字节码: 00 00 00 09
# 	指令: pl_data_length_4b	字节码: 00 00 00 80
# 	指令: ps_ddr_addr      	字节码: 00 00 00 0a
# 	指令: pl_data_length_4b	字节码: 00 00 00 01
# 	指令: ps_ddr_addr      	字节码: 00 00 00 8a
# 	指令: pl_data_length_4b	字节码: 00 00 00 10
#
# Failed to send message:
# 完整字节码: 55aa0b0000008d0100000000
# 模式: 11
# 	帧头:               	字节码: 55 aa 0b
# 	指令: ps_ddr_addr   	字节码: 00 00 00 8d
# 	指令: ps_start_finsh	字节码: 01
# 	指令: ps_ddr_addr   	字节码: 00 00 00 00
#
# Failed to send message:
# 完整字节码: 55aa0b0000008e0000000000
# 模式: 11
# 	帧头:               	字节码: 55 aa 0b
# 	指令: ps_ddr_addr   	字节码: 00 00 00 8e
# 	指令: ps_start_finsh	字节码: 00
# 	指令: ps_ddr_addr   	字节码: 00 00 00 00
#
# Failed to send message:
# 接收信息错误!
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 chip.inference6(np.ones((128,16)),row_index=[0],col_index=[i for i in range(0,256,16)],read_voltage=0.1,tg=5,gain=1,sub_base=True,from_row=False,split_type=4,ps_ddr_pos=0)
#
# File d:\ZJU\上位机\ArrTest2.0_Firmware1.0_Code1.1.8\modules\chip.py:3123, in CHIP.inference6(self, data, row_index, col_index, read_voltage, tg, gain, sub_base, from_row, split_type, ps_ddr_pos)
#    3121 # 开始执行
#    3122 ps_ddr_pos = self.send_ps_run(flag=2,ps_ddr_pos_start=ps_ddr_pos_start,ps_ddr_pos=ps_ddr_pos)
# -> 3123 output = self.adc.get_out_output5(data_length=m*batch_num*(2 if sub_base else 1))
#    3124 if sub_base:
#    3125     output = output[::2,:] - output[1::2,:]
#
# File d:\ZJU\上位机\ArrTest2.0_Firmware1.0_Code1.1.8\modules\adc.py:300, in ADC.get_out_output5(self, data_length)
#     298 int16_array = np.frombuffer(message, dtype=np.dtype('>i2'))
#     299 voltage = int16_array * self.base
# --> 300 return voltage.reshape(data_length,self.setting.chip_tia_num)
#
# ValueError: cannot reshape array of size 0 into shape (256,32)

# %% [markdown]
# ### 准备输入数据并下放

# %%
# 首次运行
# start_time = time.perf_counter()
ps_ddr_pos_start = 0xA100000 // 0x20  # 至少从这个ddr地址之后存放
ps_ddr_pos = ps_ddr_pos_start

# %%
# 输入图片准备，从列输入
BATCH_SIZE = 1000  # 10000
test_loss_ = 0
correct = 0
test_samples = 0
test_loader = get_mnist_cropped(BATCH_SIZE, train=False, val=True)[0]
test_acc = []
output_row_num = 1
input_col_num = 196

test_criterion = nn.CrossEntropyLoss(reduction='sum')

max_samples = 1000  # 仅测试的最大样本数

b_col, b_row = [i for i in range(0, 128)], [0]

data_all = []

# 在数据收集阶段，为每个样本记录必要的元数据
sample_metadata = []  # 记录每个样本的元数据
current_sample_idx = 0

# 准备数据
for idx, (data, label) in enumerate(test_loader):
    if test_samples >= max_samples:
        break

    test_samples += data.size(0)
    data = data.reshape(data.shape[0], 196, 1)  # reshape为[BATCH_SIZE, H*W, 1]
    data_int = data.byte()  # 转换为 uint8 类型 [BATCH_SIZE, H*W, 1]
    binary_bits = []

    for i in range(7, -1, -1):  # 从第7位（最高位）到第0位（最低位）
        bit = (data_int >> i) & 1  # 提取第i位 [BATCH_SIZE, H*W, 1]
        binary_bits.append(bit)
    data_binary = torch.cat(binary_bits, dim=-1)  # 形状变为 [BATCH_SIZE, H*W, 8]
    for n in range(data_binary.shape[0]):
        # 为每个样本记录开始位置和位流数量
        sample_start_idx = len(data_all)
        bit_stream_count = data_binary.shape[2]  # 8个位流
        
        sample_metadata.append({
            'batch_idx': idx,
            'sample_idx': current_sample_idx,
            'data_start': sample_start_idx,
            'bit_stream_count': bit_stream_count,
            'label': label[n] if label is not None else None
            # 后续还要添加8个位的num_col_activated list
        })
        current_sample_idx += 1
        
        for k in range(data_binary.shape[2]):
            input_bit_stream = data_binary[n, :, k]  # 单次的位流输入
            input_col, output_row = [x for x, mask in zip(b_col, input_bit_stream) if mask == 1], b_row  # 这里input_bit_stream按顺序开启/关闭乱序的列号，但权重按照相同顺序提前映射好了，故是一致的

            # v_base,_,_ = chip.read4(crossbar=None,row_index=output_row,col_index=input_col,read_voltage=0,tg=5,gain=3,sub_base=False,from_row=False,split_type=3,row_type=0,col_type=0)
            # v,_,_ = chip.read4(crossbar=None,row_index=output_row,col_index=input_col,read_voltage=0.1,tg=5,gain=3,sub_base=False,from_row=False,split_type=3,row_type=0,col_type=0)
            # c = chip.voltage_to_cond(voltage = v - v_base)
            
            ps_ddr_pos,data=chip.read5(crossbar=None,row_index=output_row,col_index=input_col,read_voltage=0.1,tg=5,gain=3,sub_base=True,from_row=False,
                        split_type=3,row_type=0,col_type=0,ps_ddr_pos=ps_ddr_pos)
            data_all.append(data)

# %%
# 只测试DMA传输+执行指令时间+数据返回
start_time = time.perf_counter()

# %%
# 开始执行指令
ps_ddr_pos = chip.send_ps_run(flag=2,ps_ddr_pos_start=ps_ddr_pos_start,ps_ddr_pos=ps_ddr_pos)

overall_output = []
current_data_idx = 0
current_batch_idx = -1
batch_output = []  # 当前batch的输出列表

for sample_meta in sample_metadata:
    # 如果切换到新的batch，保存上一个batch的输出
    if sample_meta['batch_idx'] != current_batch_idx:
        if batch_output:  # 如果batch_output不为空，添加到overall_output
            overall_output.extend(batch_output)
        batch_output = []  # 重置为新的batch
        current_batch_idx = sample_meta['batch_idx']
    
    sample_output = np.zeros(output_row_num)
    
    # 处理当前样本的所有位流
    for bit_idx in range(sample_meta['bit_stream_count']):
        if current_data_idx < len(data_all):
            data_item = data_all[current_data_idx]

            v, c, r = chip.get_read5(*data_item)

            current_data_idx += 1
            
            partial_output = c[b_row]
            
            bit_weight = 2 ** (7 - bit_idx)  # 最高位权重128，最低位权重1
            sample_output += partial_output * bit_weight
    
    # 将当前样本输出添加到batch_output中
    batch_output.append(sample_output)
# 添加最后一个batch的输出
if batch_output:
    overall_output.extend(batch_output)
# 转换为tensor便于后续计算
overall_output = torch.tensor(np.array(overall_output), dtype=torch.float32)

print(f"处理完成: 总共{len(overall_output)}个样本，{len(sample_metadata)}个元数据记录")

chip.ps.receive_packet_check(bytes_num=4,message_check="cc550000")

end_time = time.perf_counter()
elapsed_time = end_time - start_time
print(f"DDR方法总用时: {elapsed_time:.6f} seconds")

# %%
print(len(data_all))

# %%
print(current_data_idx)

# %%
print(hex(ps_ddr_pos))

# %%
import time
import os
import numpy as np
import sys
sys.path.append(os.path.dirname(os.getcwd()))
from modules import CHIP

# %%
chip=CHIP(local_ip="192.168.1.15",remote_ip="192.168.1.12",remote_port=7,debug=0,init=True)
chip.set_device_cfg(deviceType=1,IsNew32=True,IsRERAM512=False)
chip.adc.set_gap(adc_cs_gap=100,adc_first_gap=20,adc_last_gap=20)
chip.adc.set_gain_resistor(big_resistance=22e-3,small_resistance=200)
chip.clk_manager.set_cyc(delay1=10,delay2=10,delay3=50)
chip.add_compiler("../compiler/code/")
# Out:
# Failed to connect: [WinError 10049] 在其上下文中，该请求的地址无效。
# Failed to send message:
# Failed to send message:
# Failed to send message:
# Failed to send message:
# Failed to send message:
# Failed to send message:
# Failed to send message:
# Failed to send message:
# Failed to send message:
# Failed to send message:
# 正在编译文件:  ../compiler/code/asm_ds.txt
# 编译指令 set_elewise_reg_2_shifter1 reg5 时出错: 变量reg5未定义!
# 编译指令 sll reg13, reg4, reg12 时出错: 变量reg4未定义!
# 编译指令 sub reg15, reg0, reg2 时出错: 变量reg0未定义!
# 编译指令 add reg15, reg15, reg10 时出错: 变量reg15未定义!
# 编译指令 cmp_r reg14, reg15 时出错: 变量reg14未定义!
# 编译指令 cmp_r reg16, reg1 时出错: 变量reg16未定义!
# 编译指令 cmp_r reg17, reg2 时出错: 变量reg17未定义!
# 编译指令 add reg18, reg14, reg17 时出错: 变量reg14未定义!
# 编译指令 sll reg19, reg18, reg9 时出错: 变量reg18未定义!
# 编译指令 add reg20, reg19, reg16 时出错: 变量reg19未定义!
# 编译指令 add reg21, reg20, reg3 时出错: 变量reg20未定义!
# 编译指令 set_actv_ram_addr reg21 时出错: 变量reg21未定义!
# 编译指令 set_reshape_buffer_addr reg17 时出错: 变量reg17未定义!
# 编译指令 add reg17, reg17, reg10 时出错: 变量reg17未定义!
# 编译指令 set_actv_ram_addr reg13 时出错: 变量reg13未定义!
# 编译指令 add reg13, reg13, reg7 时出错: 变量reg13未定义!
# 编译指令 add reg16, reg16, reg10 时出错: 变量reg16未定义!
# 编译指令 add reg14, reg14, reg10 时出错: 变量reg14未定义!
# 编译指令 cmp_i reg56, 2 时出错: 变量reg56未定义!
# 编译指令 cmp_i reg56, 0 时出错: 变量reg56未定义!
# 编译指令 set_elewise_reg_2_mul_b reg62 时出错: 变量reg62未定义!
# 编译指令 cmp_r reg57, reg8 时出错: 变量reg57未定义!
# 编译指令 set_elewise_reg_2_shifter0 reg57 时出错: 变量reg57未定义!
# 编译指令 cmp_r reg58, reg55 时出错: 变量reg58未定义!
# 编译指令 sll reg60, reg57, reg59 时出错: 变量reg57未定义!
# 编译指令 add reg61, reg60, reg58 时出错: 变量reg60未定义!
# 编译指令 load_reshape_buffer_t reg56, reg62, reg61 时出错: 变量reg56未定义!
# 编译指令 sll reg59, reg63, reg58 时出错: 变量reg63未定义!
# 编译指令 set_row_bank_and_data_r reg59, reg62 时出错: 变量reg59未定义!
# 编译指令 sub reg60, reg55, reg63 时出错: 变量reg55未定义!
# 编译指令 cmp_r reg58, reg60 时出错: 变量reg58未定义!
# 编译指令 add reg58, reg58, reg63 时出错: 变量reg58未定义!
# 编译指令 add reg57, reg57, reg63 时出错: 变量reg57未定义!
# 编译指令 add reg56, reg56, reg63 时出错: 变量reg56未定义!
# 编译指令 ret 时出错: 变量reg63未定义!
# 正在编译文件:  ../compiler/code/汇编指令解释测试.txt
# 编译指令 free_reg reg1 时出错: 变量reg1未定义!
# 编译指令 bge_r reg1,reg0,label 时出错: 变量reg1未定义!
# 编译指令 add_i reg1,reg0,imm 时出错: 变量reg0未定义!
# 编译指令 load_din_ram_to_reg reg1,reg0 时出错: 变量reg0未定义!
# 编译指令 add_r reg2,reg1,reg0 时出错: 变量reg1未定义!
# 编译指令 sub_r reg2,reg1,reg0 时出错: 变量reg1未定义!
# 编译指令 xor_i reg1,reg0,imm 时出错: 变量reg0未定义!
# 编译指令 sll reg2,reg1,reg0 时出错: 变量reg1未定义!
# 编译指令 srl reg2,reg1,reg0 时出错: 变量reg1未定义!
# 编译指令 set_row_bank_and_data_r reg1,reg0 时出错: 变量reg1未定义!
# 编译指令 set_col_bank_and_data_r reg1,reg0 时出错: 变量reg1未定义!
# 编译指令 row_read_rram_1ch_to_dout reg2,reg1,reg0 时出错: 变量reg2未定义!
# 编译指令 col_read_rram_1ch_to_dout reg2,reg1,reg0 时出错: 变量reg2未定义!
# 编译指令 return_dout reg2,reg1,reg0 时出错: 变量reg2未定义!
# 编译指令 row_read_rram_1ch_to_reg reg1,reg0 时出错: 变量reg1未定义!
# 编译指令 col_read_rram_1ch_to_reg reg1,reg0 时出错: 变量reg1未定义!
# 编译指令 element_wise reg0,imm0,mode 时出错: 变量reg0未定义!
# 编译指令 set_elewise_reg_2_mul_b reg2 时出错: 变量reg2未定义!
# 编译指令 set_elewise_reg_2_shifter0 reg2 时出错: 变量reg2未定义!
# 编译指令 set_elewise_reg_2_shifter1 reg2 时出错: 变量reg2未定义!
# 编译指令 set_actv_ram_addr reg0 时出错: 变量reg0未定义!
# 编译指令 set_reshape_buffer_addr reg0 时出错: 变量reg0未定义!
# 编译指令 load_reshape_buffer_t reg2,reg1,reg0 时出错: 变量reg2未定义!
# 编译指令 mov_r reg2,reg1 时出错: 变量reg1未定义!
# 编译指令 cmp_i reg0,imm0 时出错: 变量reg0未定义!
# 编译指令 cmp_r reg2,reg1 时出错: 变量reg2未定义!
# 编译指令 jmp_r reg2 时出错: 'COMPILER' object has no attribute 'jmp_r'
# 编译指令 mul reg2,reg1,reg0 时出错: 变量reg1未定义!

# %%
def add_compiler(self,directory:str,encoding:str = 'utf-8'):
    """
        增加汇编代码
    """
    for root, dirs, files in os.walk(directory):
        for file in files:
            if file.endswith('.txt'):
                self.compilers[file] = COMPILER()
                self.compilers[file].load_assembler_ins(os.path.join(root, file),encoding)

# %%
filename="../compiler/code/汇编指令解释测试.txt"
compiler = COMPILER()
simulator = SIMULATOR()
compiler.load_assembler_ins(filename,encoding="utf-8")
# 输出调试信息，显示寄存器
# print(compiler)
print(compiler.get_assembler_ins())

# 输出指令调试信息，显示最后的字节码
pkt = Packet()
pkt.append_single(compiler.get_ins_data(),mode=4)
cmd = pkt.get_bytes_list()[0]

print(cmd)


chip.ps.send_packets(pkt)
# 执行汇编代码
ins_data = compiler.get_ins_data()
chip.execute_ins(ins_data=ins_data,ins_ram_start=0)
# Out:
# 正在编译文件:  ../compiler/code/汇编指令解释测试.txt
# 编译指令 jmp_r reg2 时出错: 'COMPILER' object has no attribute 'jmp_r'
# 	consti	imm, 10
# 	consti	imm0, 10
# 	consti	imm1, 10
# 	consti	mode, 1
# 	mov_i	reg8, 0
# 	mov_i	reg0, 1
# 	mov_i	reg1, 2
# 	mov_i	reg2, 3
#
# label:
# 	jmp	label
# 	row_bank	imm1, imm0
# 	col_bank	imm1, imm0
# 	dac_v	imm1, imm0
# 	read_row_pulse	imm
# 	read_col_pulse	imm
# 	write_row_pulse
# 	write_col_pulse
# 	cim_rstn
# 	bge	reg1, reg0, label
# 	addi	reg1, reg0, imm
# 	exit
# 	load_din_ram	reg1, reg0
# 	add	reg2, reg1, reg0
# 	sub	reg2, reg1, reg0
# 	xori	reg1, reg0, imm
# 	sll	reg2, reg1, reg0
# 	srl	reg2, reg1, reg0
# 	set_row_bank	reg1, reg0
# 	set_col_bank	reg1, reg0
# 	read_row_pulse_tia	reg2, reg1, reg0
# 	read_col_pulse_tia	reg2, reg1, reg0
# 	return_dout	reg2, reg1, reg0
# 	read_row_pulse_reg	reg1, reg0
# 	read_col_pulse_reg	reg1, reg0
# 	row_ctrli	imm0
# 	col_ctrli	imm0
# 	row_col_swi	imm0
# 	read_row_pulse_diff
# 	read_col_pulse_diff
# 	cal_ch_mask	imm1, imm0
# 	apu_mode	mode
# 	apu_mode	0
# 	apu_mode	1
# 	apu_mode	2
# 	element_wise	reg0, imm0, mode
# 	element_wise	, 0, 0
# 	element_wise	, 0, 1
# 	element_wise	, 0, 2
# 	element_wise	, 0, 3
# 	element_wise	, 0, 4
# 	element_wise	reg2, 0, 5
# 	element_wise	reg2, 0, 6
# 	element_wise	, 0, 7
# 	element_wise	, 0, 8
# 	element_wise	, 0, 9
# 	element_wise	, 0, 10
# 	element_wise	, 0, 11
# 	element_wise	, 0, 12
# 	element_wise	, 0, 13
# 	element_wise	, 0, 14
# 	element_wise	reg2, 0, 15
# 	actv_ram_addr	reg0
# 	actv_ram_read
# 	actv_ram_write	mode
# 	actv_ram_write	0
# 	actv_ram_write	1
# 	actv_ram_write	2
# 	reshape_buffer_clear
# 	reshape_buffer_addr	reg0
# 	reshape_buffer_write
# 	reshape_buffer_read	reg2, reg1, reg0
# 	set_adc_discard_nbits	imm
#
# ir_ram_addr:
# 	mov_i	reg10, imm0
# 	mov_r	reg2, reg1
# 	cmp_i	reg0, imm0
# 	cmp_r	reg2, reg1
# 	jeq	ir_ram_addr
# 	jne	ir_ram_addr
# 	jlt	ir_ram_addr
# 	jgt	ir_ram_addr
# 	jle	ir_ram_addr
# 	jle	ir_ram_addr
# 	mul_r	reg2, reg1, reg0
#
# b'U\xaa\x040\x08\x00\x000\x00\x00\x010\x01\x00\x020\x02\x00\x03\x00\x00\x00\x04\x01\x00\n\n\x02\x00\n\n\x03\n\x00\n\x04\x00\x00\n\x05\x00\x00\n\x06\x00\x00\x00\x07\x00\x00\x00\x08\x00\x00\x00\t\x01\x01\x00\n\n\x01\x00\x0b\x00\x00\x00\x0c\x00\x01\x00\r\x02\x01\x00\x0e\x02\x01\x00\x0f\n\x01\x00\x10\x02\x01\x00\x11\x02\x01\x00\x12\x00\x01\x00\x13\x00\x01\x00\x14\x02\x01\x00\x15\x02\x01\x00\x16\x02\x01\x00\x17\x00\x01\x00\x18\x00\x01\x00\x19\n\x00\x00\x1a\n\x00\x00\x1b\n\x00\x00\x1c\x00\x00\x00\x1d\x00\x00\x00\x1f\x00\n\n \x00\x00\x01 \x00\x00\x00 \x00\x00\x01 \x00\x00\x02!\x00\n\x01!\x00\x00\x00!\x00\x00\x01!\x00\x00\x02!\x00\x00\x03!\x00\x00\x04!\x02\x00\x05!\x02\x00\x06!\x00\x00\x07!\x00\x00\x08!\x00\x00\t!\x00\x00\n!\x00\x00\x0b!\x00\x00\x0c!\x00\x00\r!\x00\x00\x0e!\x02\x00\x0f"\x00\x00\x00#\x00\x00\x00$\x00\x00\x01$\x00\x00\x00$\x00\x00\x01$\x00\x00\x02%\x00\x00\x00&\x00\x00\x00\'\x00\x00\x00(\x02\x01\x00)\x00\x00\n0\n\x00\n1\x02\x01\x002\x00\x00\n3\x02\x01\x004\x00\x00C5\x00\x00C6\x00\x00C7\x00\x00C8\x00\x00C9\x00\x00C;\x02\x01\x00'
# 完整字节码: ...
# 模式: 4
# 	帧头:                         	字节码: 55 aa 04
# 	指令: pl_mov_i                	字节码: 30080000
# 	指令: pl_mov_i                	字节码: 30000001
# 	指令: pl_mov_i                	字节码: 30010002
# 	指令: pl_mov_i                	字节码: 30020003
# 	指令: pl_jmp                  	字节码: 00000004
# 	指令: pl_row_bank             	字节码: 01000a0a
# 	指令: pl_col_bank             	字节码: 02000a0a
# 	指令: pl_dac_v                	字节码: 030a000a
# 	指令: pl_read_row_pulse       	字节码: 0400000a
# 	指令: pl_read_col_pulse       	字节码: 0500000a
# 	指令: pl_write_row_pulse      	字节码: 06000000
# 	指令: pl_write_col_pulse      	字节码: 07000000
# 	指令: pl_cim_rstn             	字节码: 08000000
# 	指令: pl_bge                  	字节码: 09010100
# 	指令: pl_addi                 	字节码: 0a0a0100
# 	指令: pl_exit                 	字节码: 0b000000
# 	指令: pl_load_din_ram         	字节码: 0c000100
# 	指令: pl_add                  	字节码: 0d020100
# 	指令: pl_sub                  	字节码: 0e020100
# 	指令: pl_xori                 	字节码: 0f0a0100
# 	指令: pl_sll                  	字节码: 10020100
# 	指令: pl_srl                  	字节码: 11020100
# 	指令: pl_set_row_bank         	字节码: 12000100
# 	指令: pl_set_col_bank         	字节码: 13000100
# 	指令: pl_read_row_pulse_tia   	字节码: 14020100
# 	指令: pl_read_col_pulse_tia   	字节码: 15020100
# 	指令: pl_return_dout          	字节码: 16020100
# 	指令: pl_read_row_pulse_reg   	字节码: 17000100
# 	指令: pl_read_col_pulse_reg   	字节码: 18000100
# 	指令: pl_row_ctrli            	字节码: 190a0000
# 	指令: pl_col_ctrli            	字节码: 1a0a0000
# 	指令: pl_row_col_swi          	字节码: 1b0a0000
# 	指令: pl_read_row_pulse_diff  	字节码: 1c000000
# 	指令: pl_read_col_pulse_diff  	字节码: 1d000000
# 	指令: pl_cal_ch_mask          	字节码: 1f000a0a
# 	指令: pl_apu_mode             	字节码: 20000001
# 	指令: pl_apu_mode             	字节码: 20000000
# 	指令: pl_apu_mode             	字节码: 20000001
# 	指令: pl_apu_mode             	字节码: 20000002
# 	指令: pl_element_wise         	字节码: 21000a01
# 	指令: pl_element_wise         	字节码: 21000000
# 	指令: pl_element_wise         	字节码: 21000001
# 	指令: pl_element_wise         	字节码: 21000002
# 	指令: pl_element_wise         	字节码: 21000003
# 	指令: pl_element_wise         	字节码: 21000004
# 	指令: pl_element_wise         	字节码: 21020005
# 	指令: pl_element_wise         	字节码: 21020006
# 	指令: pl_element_wise         	字节码: 21000007
# 	指令: pl_element_wise         	字节码: 21000008
# 	指令: pl_element_wise         	字节码: 21000009
# 	指令: pl_element_wise         	字节码: 2100000a
# 	指令: pl_element_wise         	字节码: 2100000b
# 	指令: pl_element_wise         	字节码: 2100000c
# 	指令: pl_element_wise         	字节码: 2100000d
# 	指令: pl_element_wise         	字节码: 2100000e
# 	指令: pl_element_wise         	字节码: 2102000f
# 	指令: pl_actv_ram_addr        	字节码: 22000000
# 	指令: pl_actv_ram_read        	字节码: 23000000
# 	指令: pl_actv_ram_write       	字节码: 24000001
# 	指令: pl_actv_ram_write       	字节码: 24000000
# 	指令: pl_actv_ram_write       	字节码: 24000001
# 	指令: pl_actv_ram_write       	字节码: 24000002
# 	指令: pl_reshape_buffer_clear 	字节码: 25000000
# 	指令: pl_reshape_buffer_addr  	字节码: 26000000
# 	指令: pl_reshape_buffer_write 	字节码: 27000000
# 	指令: pl_reshape_buffer_read  	字节码: 28020100
# 	指令: pl_set_adc_discard_nbits	字节码: 2900000a
# 	指令: pl_mov_i                	字节码: 300a000a
# 	指令: pl_mov_r                	字节码: 31020100
# 	指令: pl_cmp_i                	字节码: 3200000a
# 	指令: pl_cmp_r                	字节码: 33020100
# 	指令: pl_jeq                  	字节码: 34000043
# 	指令: pl_jne                  	字节码: 35000043
# 	指令: pl_jlt                  	字节码: 36000043
# 	指令: pl_jgt                  	字节码: 37000043
# 	指令: pl_jle                  	字节码: 38000043
# 	指令: pl_jle                  	字节码: 39000043
# 	指令: pl_mul_r                	字节码: 3b020100
#
# Failed to send message:
# 完整字节码: ...
# 模式: 4
# 	帧头:                         	字节码: 55 aa 04
# 	指令: pl_ram_addr             	字节码: 0000
# 	指令: pl_data_length          	字节码: 004f
# 	指令: pl_mov_i                	字节码: 30080000
# 	指令: pl_mov_i                	字节码: 30000001
# 	指令: pl_mov_i                	字节码: 30010002
# 	指令: pl_mov_i                	字节码: 30020003
# 	指令: pl_jmp                  	字节码: 00000004
# 	指令: pl_row_bank             	字节码: 01000a0a
# 	指令: pl_col_bank             	字节码: 02000a0a
# 	指令: pl_dac_v                	字节码: 030a000a
# 	指令: pl_read_row_pulse       	字节码: 0400000a
# 	指令: pl_read_col_pulse       	字节码: 0500000a
# 	指令: pl_write_row_pulse      	字节码: 06000000
# 	指令: pl_write_col_pulse      	字节码: 07000000
# 	指令: pl_cim_rstn             	字节码: 08000000
# 	指令: pl_bge                  	字节码: 09010100
# 	指令: pl_addi                 	字节码: 0a0a0100
# 	指令: pl_exit                 	字节码: 0b000000
# 	指令: pl_load_din_ram         	字节码: 0c000100
# 	指令: pl_add                  	字节码: 0d020100
# 	指令: pl_sub                  	字节码: 0e020100
# 	指令: pl_xori                 	字节码: 0f0a0100
# 	指令: pl_sll                  	字节码: 10020100
# 	指令: pl_srl                  	字节码: 11020100
# 	指令: pl_set_row_bank         	字节码: 12000100
# 	指令: pl_set_col_bank         	字节码: 13000100
# 	指令: pl_read_row_pulse_tia   	字节码: 14020100
# 	指令: pl_read_col_pulse_tia   	字节码: 15020100
# 	指令: pl_return_dout          	字节码: 16020100
# 	指令: pl_read_row_pulse_reg   	字节码: 17000100
# 	指令: pl_read_col_pulse_reg   	字节码: 18000100
# 	指令: pl_row_ctrli            	字节码: 190a0000
# 	指令: pl_col_ctrli            	字节码: 1a0a0000
# 	指令: pl_row_col_swi          	字节码: 1b0a0000
# 	指令: pl_read_row_pulse_diff  	字节码: 1c000000
# 	指令: pl_read_col_pulse_diff  	字节码: 1d000000
# 	指令: pl_cal_ch_mask          	字节码: 1f000a0a
# 	指令: pl_apu_mode             	字节码: 20000001
# 	指令: pl_apu_mode             	字节码: 20000000
# 	指令: pl_apu_mode             	字节码: 20000001
# 	指令: pl_apu_mode             	字节码: 20000002
# 	指令: pl_element_wise         	字节码: 21000a01
# 	指令: pl_element_wise         	字节码: 21000000
# 	指令: pl_element_wise         	字节码: 21000001
# 	指令: pl_element_wise         	字节码: 21000002
# 	指令: pl_element_wise         	字节码: 21000003
# 	指令: pl_element_wise         	字节码: 21000004
# 	指令: pl_element_wise         	字节码: 21020005
# 	指令: pl_element_wise         	字节码: 21020006
# 	指令: pl_element_wise         	字节码: 21000007
# 	指令: pl_element_wise         	字节码: 21000008
# 	指令: pl_element_wise         	字节码: 21000009
# 	指令: pl_element_wise         	字节码: 2100000a
# 	指令: pl_element_wise         	字节码: 2100000b
# 	指令: pl_element_wise         	字节码: 2100000c
# 	指令: pl_element_wise         	字节码: 2100000d
# 	指令: pl_element_wise         	字节码: 2100000e
# 	指令: pl_element_wise         	字节码: 2102000f
# 	指令: pl_actv_ram_addr        	字节码: 22000000
# 	指令: pl_actv_ram_read        	字节码: 23000000
# 	指令: pl_actv_ram_write       	字节码: 24000001
# 	指令: pl_actv_ram_write       	字节码: 24000000
# 	指令: pl_actv_ram_write       	字节码: 24000001
# 	指令: pl_actv_ram_write       	字节码: 24000002
# 	指令: pl_reshape_buffer_clear 	字节码: 25000000
# 	指令: pl_reshape_buffer_addr  	字节码: 26000000
# 	指令: pl_reshape_buffer_write 	字节码: 27000000
# 	指令: pl_reshape_buffer_read  	字节码: 28020100
# 	指令: pl_set_adc_discard_nbits	字节码: 2900000a
# 	指令: pl_mov_i                	字节码: 300a000a
# 	指令: pl_mov_r                	字节码: 31020100
# 	指令: pl_cmp_i                	字节码: 3200000a
# 	指令: pl_cmp_r                	字节码: 33020100
# 	指令: pl_jeq                  	字节码: 34000043
# 	指令: pl_jne                  	字节码: 35000043
# 	指令: pl_jlt                  	字节码: 36000043
# 	指令: pl_jgt                  	字节码: 37000043
# 	指令: pl_jle                  	字节码: 38000043
# 	指令: pl_jle                  	字节码: 39000043
# 	指令: pl_mul_r                	字节码: 3b020100
# 	指令: pl_exit                 	字节码: 0b000000
#
# Failed to send message:
# 完整字节码: 55aa010100008000
# 模式: 1
# 	帧头:               	字节码: 55 aa 01
# 	指令: fast_command_1	字节码: 0100008000
#
# Failed to send message:

# %%
chip=CHIP(PS("192.168.1.10", 7,debug=0),init=True)
chip.set_device_cfg(0)
chip.clk_manager.set_cyc(100,200)
chip.add_compiler("../code/")

# %%
filename="../code/读任意大小的块-汇编代码示例.txt"
compiler = COMPILER()
simulator = SIMULATOR()
compiler.load_assembler_ins(filename,encoding="utf-8")

const_data,row_data,col_data = chip.send_din_ram3(0,1,127,128,0)
for k,v in const_data.items():
    compiler.add_const_variable(k,v)
compiler.add_const_variable("count_max_c",128)
compiler.add_const_variable("pq_c",0)

chip.execute_ins(compiler.get_ins_data(),0,message_check=None)
message = chip.ps.receive_packet(32).hex()
print([message[i*4:(i*4+4)] for i in range(16)])

message = chip.ps.receive_packet(4)
print(message)

din_data = chip.ps.historic_pkts[-3].get_bytes_list()[0]
ins_data = chip.ps.historic_pkts[-2].get_bytes_list()[0]

# print(chip.ps.historic_pkts[-3])
# print(chip.ps.historic_pkts[-2])
simulator.load_bit_cmd(din_data)
simulator.load_bit_cmd(ins_data)

# %%
message=chip.adc.return_dout(1,0)
tmp = [message[i*4:(i*4+4)] for i in range(16)]
print(tmp)
print(chip.adc.get_out2(1,0))

# %%
print(chip.setting.get_bank_index_tia([63,64],True))

# %%
for k,v in const_data.items():
    print(k,v)

# %%
# [(0, 63, 4, 31, 1), (1, 64, 1, 0, 10)]
# simulator.reset()

# %%
simulator.execut_one()
simulator.print_reg()
simulator.print_din_ram()

# %%
print(hex(simulator.din_ram[0x11]))

# %% [markdown]
# ### 1.从汇编文件中加载汇编代码

# %%
filename="../compiler/code/汇编测试代码.txt"
compiler = COMPILER()
simulator = SIMULATOR()
compiler.load_assembler_ins(filename,encoding="utf-8")
# 输出调试信息，显示寄存器
# print(compiler)
# print(compiler.get_assembler_ins())

# 输出指令调试信息，显示最后的字节码
pkt = Packet()
pkt.append_single(compiler.get_ins_data(),mode=4)
cmd = pkt.get_bytes_list()[0]

print(cmd)


# chip.ps.send_packets(pkt)
# # 执行汇编代码
# ins_data = compiler.get_ins_data()
# chip.execute_ins(ins_data=ins_data,ins_ram_start=0)

# %%
compiler = COMPILER()
compiler.load_assembler_ins("../assembler_code/汇编测试代码.txt",encoding="utf-8")
print(compiler)
# compiler.add_offset(offset=10)
# print(compiler)
# compiler.add_offset(offset=9)
# pkt = Packet()
# pkt.append_single(compiler.get_ins_data(),mode=4)
# ins2= str(pkt)

# print(compiler)

# %% [markdown]
# ### 2.模拟汇编代码的运行

# %%
filename="../code/读单点测试.txt"
compiler = COMPILER()
simulator = SIMULATOR()
compiler.load_assembler_ins(filename,encoding="utf-8")


pkt = Packet()
pkt.append_single(compiler.get_ins_data(),mode=4)
cmd = pkt.get_bytes_list()[0]

chip.ps.send_packets(pkt)
simulator.load_bit_cmd(cmd)

# %%
simulator.execut_one()
simulator.print_reg()

# %%
# for i in range(simulator.ins_num):
#     print(hex(simulator.ins_ram[i]))

# print("\n\n")
# for i in range(simulator.din_num):
#     print(hex(simulator.din_ram[i]))

# %% [markdown]
# ### 2.通过手动调用函数写汇编代码

# %%
compiler = COMPILER()
# 首先定义和声明能当立即数使用的常量变量
compiler.consti("row_bank_start_c",3)
compiler.consti("row_bank_end_c",4)
compiler.consti("col_bank_start_c",3)
compiler.consti("col_bank_end_c",4)

compiler.consti("count_max_c",512)
compiler.consti("pq_c",0)

compiler.consti("row_index_din_ram_s_c",0)
compiler.consti("row_index_din_ram_e_c",2)

compiler.consti("col_index_din_ram_s_c",4)
compiler.consti("col_index_din_ram_e_c",6)

# 正式的汇编代码开始
compiler.add_label("start")
compiler.addi("row_bank_start","zero","row_bank_start_c")
compiler.addi("row_bank_end","zero","row_bank_end_c")
compiler.addi("col_bank_start","zero","col_bank_start_c")
compiler.addi("col_bank_end","zero","col_bank_end_c")

compiler.addi("shift_one", "zero", 1)
compiler.addi("shift_four", "zero", 4)
compiler.addi("four", "zero", 4)
compiler.addi("count", "zero", 0)
compiler.addi("count_max", "zero", "count_max_c")
compiler.addi("pq", "zero", "pq_c")

# ------------------------------------------------------------
compiler.addi("row_index_start_addr","zero","row_index_din_ram_s_c")
compiler.addi("row_index_end_addr","zero","row_index_din_ram_e_c")

compiler.addi("row_bank_mask","zero",0x1)
compiler.sll("row_bank_mask","row_bank_mask","row_bank_start")
compiler.addi("row_bank_count","row_bank_start",0)

compiler.add_label("loop1")

# ------------------------------------------------------------
compiler.load_din_ram("row_index_count","row_index_start_addr")
compiler.load_din_ram("row_end_index","row_index_end_addr")
compiler.addi("row_index_mask", "zero", 0x1)
compiler.sll("row_index_mask", "row_index_mask", "row_index_count")
compiler.set_row_bank("row_bank_mask", "row_index_mask")

compiler.add_label("loop2")
compiler.addi("col_index_start_addr", "zero", "col_index_din_ram_s_c")
compiler.addi("col_index_end_addr", "zero", "col_index_din_ram_e_c")
compiler.addi("col_bank_mask", "zero", 0x1)
compiler.sll("col_bank_mask","col_bank_mask","col_bank_start")
compiler.addi("col_bank_count", "col_bank_start", 0)

compiler.add_label("loop3")
compiler.load_din_ram("col_index_count","col_index_start_addr")
compiler.load_din_ram("col_end_index","col_index_end_addr")
compiler.addi("col_index_mask", "zero", 0x1)
compiler.sll("col_index_mask","col_index_mask","col_index_count")

compiler.bge("col_bank_count", "four", "tia_big4")
compiler.add_label("tia_nobig4")
compiler.add("tmp_bank", "col_bank_count", "four")
compiler.jump("tia_end")
compiler.add_label("tia_big4")
compiler.sub("tmp_bank", "col_bank_count", "four")
compiler.add_label("tia_end")
compiler.sll("tmp_bank", "tmp_bank", "shift_one")

compiler.add_label("loop4")
compiler.srl("tmp_index", "col_index_count", "shift_four")
compiler.add("tia", "tmp_bank", "tmp_index")
compiler.set_col_bank("col_bank_mask", "col_index_mask")

compiler.read_row_pulse_tia("tia", "count", "pq")
compiler.addi("count", "count", 1)
compiler.bge("count", "count_max", "return_res")
compiler.jump("jump_return")
compiler.add_label("return_res")
compiler.return_dout("count", "zero", "pq")
compiler.xori("pq", "pq", 1)
compiler.addi("count", "zero", 0)
compiler.add_label("jump_return")
compiler.bge("col_index_count", "col_end_index", "end4")
compiler.addi("col_index_count", "col_index_count", 1)
compiler.sll("col_index_mask", "col_index_mask", "shift_one")
compiler.jump("loop4")

compiler.add_label("end4")
compiler.set_col_bank("col_bank_mask", "zero")
compiler.bge("col_bank_count", "col_bank_end", "end3")
compiler.addi("col_bank_count", "col_bank_count", 1)
compiler.sll("col_bank_mask", "col_bank_mask", "shift_one")
compiler.addi("col_index_start_addr", "col_index_start_addr", 1)
compiler.addi("col_index_end_addr", "col_index_end_addr", 1)
compiler.jump("loop3")

compiler.add_label("end3")
compiler.bge("row_index_count", "row_end_index", "end2")
compiler.addi("row_index_count", "row_index_count", 1)
compiler.sll("row_index_mask", "row_index_mask", "shift_one")
compiler.jump("loop2")

compiler.add_label("end2")
compiler.set_row_bank("row_bank_mask", "zero")
compiler.bge("row_bank_count", "row_bank_end", "end1")
compiler.addi("row_bank_count", "row_bank_count", 1)
compiler.sll("row_bank_mask", "row_bank_mask", "shift_one")
compiler.addi("row_index_start_addr", "row_index_start_addr", 1)
compiler.addi("row_index_end_addr", "row_index_end_addr", 1)
compiler.jump("loop1")

compiler.add_label("end1")
compiler.return_dout("count", "zero", "pq")
compiler.exit()

pkt = Packet()
pkt.append_single(compiler.get_ins_data(),mode=4)
ins1= str(pkt)

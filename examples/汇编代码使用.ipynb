# %%
import time
import os
import numpy as np
import sys
sys.path.append(os.path.dirname(os.getcwd()))
from modules import CHIP
from command import CMD,CmdData,PL_DATA

# %%
chip=CHIP(local_ip="192.168.1.15",remote_ip="192.168.1.12",remote_port=7,debug=0,init=True)
chip.set_device_cfg(deviceType=1,IsNew32=True,IsRERAM512=False)
chip.adc.set_gap(adc_cs_gap=100,adc_first_gap=20,adc_last_gap=20)
chip.adc.set_gain_resistor(big_resistance=22e-3,small_resistance=200)
chip.clk_manager.set_cyc(delay1=10,delay2=10,delay3=50)
chip.add_compiler("../compiler/code/")
# Out:
# Failed to connect: [WinError 10049] 在其上下文中，该请求的地址无效。
# Failed to send message:
# Failed to send message:
# Failed to send message:
# Failed to send message:
# Failed to send message:
# Failed to send message:
# Failed to send message:
# Failed to send message:
# Failed to send message:
# Failed to send message:
# 正在编译文件:  ../compiler/code/asm_ds.asm
# 正在编译文件:  ../compiler/code/delay配置测试.asm
# 正在编译文件:  ../compiler/code/汇编指令解释测试.asm

# %%
chip.execute_asm(file_path="../compiler/code/delay配置测试.asm",const_data = None,din_data=None)
# Out:
# 正在编译文件:  ../compiler/code/delay配置测试.asm
# Failed to send message:
# Failed to send message:
# Failed to send message:

# %%
din_data = [
    # set_row_ctrl_pulse_para
    CMD(PL_DATA,command_data = CmdData(0x0000_0000)),  # 模式
    CMD(PL_DATA,command_data = CmdData(1000)),  # delay
    CMD(PL_DATA,command_data = CmdData(1000)),  # pulse width

    # set_col_ctrl_pulse_para
    CMD(PL_DATA,command_data = CmdData(0x0000_0000)),  # 模式
    CMD(PL_DATA,command_data = CmdData(1000)),  # delay
    CMD(PL_DATA,command_data = CmdData(1000)),  # pulse width

    # set_tg_pulse_width_para
    CMD(PL_DATA,command_data = CmdData(0x0000_0000)),  # 模式
    CMD(PL_DATA,command_data = CmdData(1000)),  # delay
    CMD(PL_DATA,command_data = CmdData(1000)),  # pulse width

    # set_vin_row_pulse_para
    CMD(PL_DATA,command_data = CmdData(0x0000_0000)),  # 模式
    CMD(PL_DATA,command_data = CmdData(1000)),  # delay
    CMD(PL_DATA,command_data = CmdData(1000)),  # pulse width

    # set_vin_col_pulse_para
    CMD(PL_DATA,command_data = CmdData(0x0000_0000)),  # 模式
    CMD(PL_DATA,command_data = CmdData(1000)),  # delay
    CMD(PL_DATA,command_data = CmdData(1000)),  # pulse width

    # set_write_row_pulse_para
    CMD(PL_DATA,command_data = CmdData(0x0000_0000)),  # 模式
    CMD(PL_DATA,command_data = CmdData(1000)),  # delay
    CMD(PL_DATA,command_data = CmdData(1000)),  # pulse width

    # set_write_col_pulse_para
    CMD(PL_DATA,command_data = CmdData(0x0000_0000)),  # 模式
    CMD(PL_DATA,command_data = CmdData(1000)),  # delay
    CMD(PL_DATA,command_data = CmdData(1000)),  # pulse width

    # set_read_row_pulse_delay
    CMD(PL_DATA,command_data = CmdData(1000)),  # pulse width

    # set_read_col_pulse_delay
    CMD(PL_DATA,command_data = CmdData(1000)),  # pulse width
]

chip.execute_asm(file_path="../compiler/code/delay配置测试.asm",const_data = None,din_data=din_data)
# Out:
# 正在编译文件:  ../compiler/code/delay配置测试.asm
# Failed to send message:
# Failed to send message:
# Failed to send message:

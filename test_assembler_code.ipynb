# %%
import os
import sys
sys.path.append(os.path.dirname(os.getcwd()))

from command import CMD,CmdData,Packet
from compiler import COMPILER
from command.singleCmdInfo import *

# %%
filename="./code/write_verify.txt"
compiler = COMPILER()
compiler.load_assembler_ins(filename,encoding="utf-8")

# 输出调试信息，显示寄存器
print(compiler)
print(compiler.get_assembler_ins())

# 输出指令调试信息，显示最后的字节码
pkt = Packet()
pkt.append_single(compiler.get_ins_data(),mode=4)
print(pkt)

with open('ouput.txt', 'w') as file:
    file.write("输出相关调试信息:\n")
    file.write(str(compiler))

    file.write("\n\n\n汇编代码:\n")
    file.write(str(compiler.get_assembler_ins()))

    file.write("\n\n\n字节码:\n")
    file.write(str(pkt))
# Out:
# const: count_max_c                   : 常量值: 11
# const: threshold                     : 常量值: 5
# const: step_c                        : 常量值: 1
# const: TG                            : 常量值: 6
# const: ROW_VA                        : 常量值: 8
# const: COL_VA                        : 常量值: 10
# const: V_set                         : 常量值: 3
# const: V_reset                       : 常量值: 2
# const: row_bank_din_ram_s_c          : 常量值: 0
# const: row_bank_din_ram_e_c          : 常量值: 1
# const: col_bank_din_ram_s_c          : 常量值: 2
# const: col_bank_din_ram_e_c          : 常量值: 3
# const: row_index_din_ram_s_c         : 常量值: 4
# const: row_index_din_ram_e_c         : 常量值: 5
# const: col_index_din_ram_s_c         : 常量值: 6
# const: col_index_din_ram_e_c         : 常量值: 7
#
# 变量名: zero                          : 寄存器编号: 0
# 变量名: one                           : 寄存器编号: 1
# 变量名: four                          : 寄存器编号: 2
# 变量名: count                         : 寄存器编号: 3
# 变量名: count_max                     : 寄存器编号: 4
# 变量名: step                          : 寄存器编号: 5
# 变量名: a                             : 寄存器编号: 6
# 变量名: TG_offset                     : 寄存器编号: 9
# 变量名: row_bank_addr                 : 寄存器编号: 7
# 变量名: row_bank_end_addr             : 寄存器编号: 8
# 变量名: row_index_start_addr          : 寄存器编号: 10
# 变量名: row_index_end_addr            : 寄存器编号: 11
# 变量名: row_bank_mask                 : 寄存器编号: 13
# 变量名: row_index_num                 : 寄存器编号: 12
# 变量名: row_end_index                 : 寄存器编号: 14
# 变量名: row_index_mask                : 寄存器编号: 15
# 变量名: col_bank_addr                 : 寄存器编号: 16
# 变量名: col_bank_end_addr             : 寄存器编号: 17
# 变量名: col_index_start_addr          : 寄存器编号: 18
# 变量名: col_index_end_addr            : 寄存器编号: 19
# 变量名: col_bank_mask                 : 寄存器编号: 21
# 变量名: col_index_num                 : 寄存器编号: 22
# 变量名: col_end_index                 : 寄存器编号: 23
# 变量名: tia_base                      : 寄存器编号: 24
# 变量名: col_index_mask                : 寄存器编号: 20
# 变量名: tia_offset                    : 寄存器编号: 25
# 变量名: tia_mask                      : 寄存器编号: 27
# 变量名: target                        : 寄存器编号: 28
# 变量名: V_write                       : 寄存器编号: 29
# 变量名: count_verify                  : 寄存器编号: 26
# 变量名: lower                         : 寄存器编号: 30
# 变量名: upper                         : 寄存器编号: 31
#
# 标签: start                         : 指令地址: 0
# 标签: loop1                         : 指令地址: 14
# 标签: loop2                         : 指令地址: 18
# 标签: loop3                         : 指令地址: 24
# 标签: tia_nobig4                    : 指令地址: 29
# 标签: tia_big4                      : 指令地址: 31
# 标签: tia_end                       : 指令地址: 32
# 标签: loop4                         : 指令地址: 33
# 标签: loop_verify                   : 指令地址: 44
# 标签: loop_small                    : 指令地址: 51
# 标签: loop_big                      : 指令地址: 57
# 标签: jump_return                   : 指令地址: 65
# 标签: end4                          : 指令地址: 68
# 标签: end3                          : 指令地址: 74
# 标签: end2                          : 指令地址: 77
# 标签: exit                          : 指令地址: 83
#
# 0		consti	count_max_c, 11
# 0		consti	threshold, 5
# 0		consti	step_c, 1
# 0		consti	TG, 6
# 0		consti	ROW_VA, 8
# 0		consti	COL_VA, 10
# 0		consti	V_set, 3
# 0		consti	V_reset, 2
# 0		consti	row_bank_din_ram_s_c, 0
# 0		consti	row_bank_din_ram_e_c, 1
# 0		consti	col_bank_din_ram_s_c, 2
# 0		consti	col_bank_din_ram_e_c, 3
# 0		consti	row_index_din_ram_s_c, 4
# 0		consti	row_index_din_ram_e_c, 5
# 0		consti	col_index_din_ram_s_c, 6
# 0		consti	col_index_din_ram_e_c, 7
# 0	start:
# 0		addi	one, zero, 1
# 1		addi	four, zero, 4
# 2		addi	count, zero, 0
# 3		addi	count_max, zero, count_max_c
# 4		addi	step, zero, step_c
# 5		addi	a, zero, 0
# 6		addi	eight, zero, 8
# 7		addi	x, zero, 256
# 8		sll	x, x, eight
# 9		add	TG_offset, x, eight
# 10		addi	row_bank_addr, zero, row_bank_din_ram_s_c
# 11		addi	row_bank_end_addr, zero, row_bank_din_ram_e_c
# 12		addi	row_index_start_addr, zero, row_index_din_ram_s_c
# 13		addi	row_index_end_addr, zero, row_index_din_ram_e_c
#
# 14	loop1:
# 14		load_din_ram	row_bank_num, row_bank_addr
# 15		sll	row_bank_mask, one, row_bank_num
# 16		load_din_ram	row_index_num, row_index_start_addr
# 17		load_din_ram	row_end_index, row_index_end_addr
#
# 18	loop2:
# 18		sll	row_index_mask, one, row_index_num
# 19		set_row_bank	row_bank_mask, row_index_mask
# 20		addi	col_bank_addr, zero, col_bank_din_ram_s_c
# 21		addi	col_bank_end_addr, zero, col_bank_din_ram_e_c
# 22		addi	col_index_start_addr, zero, col_index_din_ram_s_c
# 23		addi	col_index_end_addr, zero, col_index_din_ram_e_c
#
# 24	loop3:
# 24		load_din_ram	col_bank_num, col_bank_addr
# 25		sll	col_bank_mask, one, col_bank_num
# 26		load_din_ram	col_index_num, col_index_start_addr
# 27		load_din_ram	col_end_index, col_index_end_addr
# 28		bge	col_bank_num, four, tia_big4
#
# 29	tia_nobig4:
# 29		add	tia_base, col_bank_num, four
# 30		jump	tia_end
#
# 31	tia_big4:
# 31		sub	tia_base, col_bank_num, four
#
# 32	tia_end:
# 32		sll	tia_base, tia_base, one
#
# 33	loop4:
# 33		sll	col_index_mask, one, col_index_num
# 34		set_col_bank	col_bank_mask, col_index_mask
# 35		srl	tia_offset, col_index_num, four
# 36		add	tia_num, tia_base, tia_offset
# 37		sll	tia_mask, one, tia_num
# 38		addi	count_target, count, 8
# 39		load_din_ram	target, count_target
# 40		add	count_TG, count, TG_offset
# 41		load_din_ram	V_write, count_TG
# 42		addi	count, count, 1
# 43		addi	count_verify, zero, 0
#
# 44	loop_verify:
# 44		bge	count_verify, count_max, jump_return
# 45		read_row_pulse_reg	tia_mask, a
# 46		addi	lower, a, threshold
# 47		bge	target, lower, loop_small
# 48		addi	upper, target, threshold
# 49		bge	a, upper, loop_big
# 50		jump	jump_return
#
# 51	loop_small:
# 51		dac_v	ROW_VA, V_set
# 52		add	V_write, V_write, step
# 53		dac_v	V_write, TG
# 54		write_row_pulse
# 55		addi	count_verify, count_verify, 1
# 56		jump	loop_verify
#
# 57	loop_big:
# 57		dac_v	COL_VA, V_reset
# 58		write_col_pulse
# 59		dac_v	ROW_VA, V_set
# 60		sub	V_write, V_write, step
# 61		dac_v	V_write, TG
# 62		write_row_pulse
# 63		addi	count_verify, count_verify, 1
# 64		jump	loop_verify
#
# 65	jump_return:
# 65		bge	col_index_num, col_end_index, end4
# 66		addi	col_index_num, col_index_num, 1
# 67		jump	loop4
#
# 68	end4:
# 68		set_col_bank	col_bank_mask, zero
# 69		bge	col_bank_addr, col_bank_end_addr, end3
# 70		addi	col_bank_addr, col_bank_addr, 1
# 71		addi	col_index_start_addr, col_index_start_addr, 1
# 72		addi	col_index_end_addr, col_index_end_addr, 1
# 73		jump	loop3
#
# 74	end3:
# 74		bge	row_index_num, row_end_index, end2
# 75		addi	row_index_num, row_index_num, 1
# 76		jump	loop2
#
# 77	end2:
# 77		set_row_bank	row_bank_mask, zero
# 78		bge	row_bank_addr, row_bank_end_addr, exit
# 79		addi	row_bank_addr, row_bank_addr, 1
# 80		addi	row_index_start_addr, row_index_start_addr, 1
# 81		addi	row_index_end_addr, row_index_end_addr, 1
# 82		jump	loop1
#
# 83	exit:
# 83		exit
#
# 	consti	count_max_c, 11
# 	consti	threshold, 5
# 	consti	step_c, 1
# 	consti	TG, 6
# 	consti	ROW_VA, 8
# 	consti	COL_VA, 10
# 	consti	V_set, 3
# 	consti	V_reset, 2
# 	consti	row_bank_din_ram_s_c, 0
# 	consti	row_bank_din_ram_e_c, 1
# 	consti	col_bank_din_ram_s_c, 2
# 	consti	col_bank_din_ram_e_c, 3
# 	consti	row_index_din_ram_s_c, 4
# 	consti	row_index_din_ram_e_c, 5
# 	consti	col_index_din_ram_s_c, 6
# 	consti	col_index_din_ram_e_c, 7
#
# start:
# 	addi	one, zero, 1
# 	addi	four, zero, 4
# 	addi	count, zero, 0
# 	addi	count_max, zero, count_max_c
# 	addi	step, zero, step_c
# 	addi	a, zero, 0
# 	addi	eight, zero, 8
# 	addi	x, zero, 256
# 	sll	x, x, eight
# 	add	TG_offset, x, eight
# 	addi	row_bank_addr, zero, row_bank_din_ram_s_c
# 	addi	row_bank_end_addr, zero, row_bank_din_ram_e_c
# 	addi	row_index_start_addr, zero, row_index_din_ram_s_c
# 	addi	row_index_end_addr, zero, row_index_din_ram_e_c
#
# loop1:
# 	load_din_ram	row_bank_num, row_bank_addr
# 	sll	row_bank_mask, one, row_bank_num
# 	load_din_ram	row_index_num, row_index_start_addr
# 	load_din_ram	row_end_index, row_index_end_addr
#
# loop2:
# 	sll	row_index_mask, one, row_index_num
# 	set_row_bank	row_bank_mask, row_index_mask
# 	addi	col_bank_addr, zero, col_bank_din_ram_s_c
# 	addi	col_bank_end_addr, zero, col_bank_din_ram_e_c
# 	addi	col_index_start_addr, zero, col_index_din_ram_s_c
# 	addi	col_index_end_addr, zero, col_index_din_ram_e_c
#
# loop3:
# 	load_din_ram	col_bank_num, col_bank_addr
# 	sll	col_bank_mask, one, col_bank_num
# 	load_din_ram	col_index_num, col_index_start_addr
# 	load_din_ram	col_end_index, col_index_end_addr
# 	bge	col_bank_num, four, tia_big4
#
# tia_nobig4:
# 	add	tia_base, col_bank_num, four
# 	jump	tia_end
#
# tia_big4:
# 	sub	tia_base, col_bank_num, four
#
# tia_end:
# 	sll	tia_base, tia_base, one
#
# loop4:
# 	sll	col_index_mask, one, col_index_num
# 	set_col_bank	col_bank_mask, col_index_mask
# 	srl	tia_offset, col_index_num, four
# 	add	tia_num, tia_base, tia_offset
# 	sll	tia_mask, one, tia_num
# 	addi	count_target, count, 8
# 	load_din_ram	target, count_target
# 	add	count_TG, count, TG_offset
# 	load_din_ram	V_write, count_TG
# 	addi	count, count, 1
# 	addi	count_verify, zero, 0
#
# loop_verify:
# 	bge	count_verify, count_max, jump_return
# 	read_row_pulse_reg	tia_mask, a
# 	addi	lower, a, threshold
# 	bge	target, lower, loop_small
# 	addi	upper, target, threshold
# 	bge	a, upper, loop_big
# 	jump	jump_return
#
# loop_small:
# 	dac_v	ROW_VA, V_set
# 	add	V_write, V_write, step
# 	dac_v	V_write, TG
# 	write_row_pulse
# 	addi	count_verify, count_verify, 1
# 	jump	loop_verify
#
# loop_big:
# 	dac_v	COL_VA, V_reset
# 	write_col_pulse
# 	dac_v	ROW_VA, V_set
# 	sub	V_write, V_write, step
# 	dac_v	V_write, TG
# 	write_row_pulse
# 	addi	count_verify, count_verify, 1
# 	jump	loop_verify
#
# jump_return:
# 	bge	col_index_num, col_end_index, end4
# 	addi	col_index_num, col_index_num, 1
# 	jump	loop4
#
# end4:
# 	set_col_bank	col_bank_mask, zero
# 	bge	col_bank_addr, col_bank_end_addr, end3
# 	addi	col_bank_addr, col_bank_addr, 1
# 	addi	col_index_start_addr, col_index_start_addr, 1
# 	addi	col_index_end_addr, col_index_end_addr, 1
# 	jump	loop3
#
# end3:
# 	bge	row_index_num, row_end_index, end2
# 	addi	row_index_num, row_index_num, 1
# 	jump	loop2
#
# end2:
# 	set_row_bank	row_bank_mask, zero
# 	bge	row_bank_addr, row_bank_end_addr, exit
# 	addi	row_bank_addr, row_bank_addr, 1
# 	addi	row_index_start_addr, row_index_start_addr, 1
# 	addi	row_index_end_addr, row_index_end_addr, 1
# 	jump	loop1
#
# exit:
# 	exit
#
# 模式: 4
# 	帧头:                      	字节码: 55 aa 04
# 	指令: pl_addi              	字节码: 0a 01 01 00
# 	指令: pl_addi              	字节码: 0a 04 02 00
# 	指令: pl_addi              	字节码: 0a 00 03 00
# 	指令: pl_addi              	字节码: 0a 0b 04 00
# 	指令: pl_addi              	字节码: 0a 01 05 00
# 	指令: pl_addi              	字节码: 0a 00 06 00
# 	指令: pl_addi              	字节码: 0a 08 07 00
# 	指令: pl_addi              	字节码: 0b 00 08 00
# 	指令: pl_sll               	字节码: 10 08 08 07
# 	指令: pl_add               	字节码: 0d 09 08 07
# 	指令: pl_addi              	字节码: 0a 00 07 00
# 	指令: pl_addi              	字节码: 0a 01 08 00
# 	指令: pl_addi              	字节码: 0a 04 0a 00
# 	指令: pl_addi              	字节码: 0a 05 0b 00
# 	指令: pl_load_din_ram      	字节码: 0c 00 0c 07
# 	指令: pl_sll               	字节码: 10 0d 01 0c
# 	指令: pl_load_din_ram      	字节码: 0c 00 0c 0a
# 	指令: pl_load_din_ram      	字节码: 0c 00 0e 0b
# 	指令: pl_sll               	字节码: 10 0f 01 0c
# 	指令: pl_set_row_bank      	字节码: 12 00 0d 0f
# 	指令: pl_addi              	字节码: 0a 02 10 00
# 	指令: pl_addi              	字节码: 0a 03 11 00
# 	指令: pl_addi              	字节码: 0a 06 12 00
# 	指令: pl_addi              	字节码: 0a 07 13 00
# 	指令: pl_load_din_ram      	字节码: 0c 00 14 10
# 	指令: pl_sll               	字节码: 10 15 01 14
# 	指令: pl_load_din_ram      	字节码: 0c 00 16 12
# 	指令: pl_load_din_ram      	字节码: 0c 00 17 13
# 	指令: pl_bge               	字节码: 09 07 d4 02
# 	指令: pl_add               	字节码: 0d 18 14 02
# 	指令: pl_jump              	字节码: 00 00 00 20
# 	指令: pl_sub               	字节码: 0e 18 14 02
# 	指令: pl_sll               	字节码: 10 18 18 01
# 	指令: pl_sll               	字节码: 10 14 01 16
# 	指令: pl_set_col_bank      	字节码: 13 00 15 14
# 	指令: pl_srl               	字节码: 11 19 16 02
# 	指令: pl_add               	字节码: 0d 1a 18 19
# 	指令: pl_sll               	字节码: 10 1b 01 1a
# 	指令: pl_addi              	字节码: 0a 08 1a 03
# 	指令: pl_load_din_ram      	字节码: 0c 00 1c 1a
# 	指令: pl_add               	字节码: 0d 1a 03 09
# 	指令: pl_load_din_ram      	字节码: 0c 00 1d 1a
# 	指令: pl_addi              	字节码: 0a 01 03 03
# 	指令: pl_addi              	字节码: 0a 00 1a 00
# 	指令: pl_bge               	字节码: 09 10 5a 04
# 	指令: pl_read_row_pulse_reg	字节码: 17 00 1b 06
# 	指令: pl_addi              	字节码: 0a 05 1e 06
# 	指令: pl_bge               	字节码: 09 0c dc 1e
# 	指令: pl_addi              	字节码: 0a 05 1f 1c
# 	指令: pl_bge               	字节码: 09 0e 46 1f
# 	指令: pl_jump              	字节码: 00 00 00 41
# 	指令: pl_dac_v             	字节码: 03 08 00 03
# 	指令: pl_add               	字节码: 0d 1d 1d 05
# 	指令: pl_dac_v             	字节码: 03 1d 00 06
# 	指令: pl_write_row_pulse   	字节码: 06 00 00 00
# 	指令: pl_addi              	字节码: 0a 01 1a 1a
# 	指令: pl_jump              	字节码: 00 00 00 2c
# 	指令: pl_dac_v             	字节码: 03 0a 00 02
# 	指令: pl_write_col_pulse   	字节码: 07 00 00 00
# 	指令: pl_dac_v             	字节码: 03 08 00 03
# 	指令: pl_sub               	字节码: 0e 1d 1d 05
# 	指令: pl_dac_v             	字节码: 03 1d 00 06
# 	指令: pl_write_row_pulse   	字节码: 06 00 00 00
# 	指令: pl_addi              	字节码: 0a 01 1a 1a
# 	指令: pl_jump              	字节码: 00 00 00 2c
# 	指令: pl_bge               	字节码: 09 11 16 17
# 	指令: pl_addi              	字节码: 0a 01 16 16
# 	指令: pl_jump              	字节码: 00 00 00 21
# 	指令: pl_set_col_bank      	字节码: 13 00 15 00
# 	指令: pl_bge               	字节码: 09 12 90 11
# 	指令: pl_addi              	字节码: 0a 01 10 10
# 	指令: pl_addi              	字节码: 0a 01 12 12
# 	指令: pl_addi              	字节码: 0a 01 13 13
# 	指令: pl_jump              	字节码: 00 00 00 18
# 	指令: pl_bge               	字节码: 09 13 4c 0e
# 	指令: pl_addi              	字节码: 0a 01 0c 0c
# 	指令: pl_jump              	字节码: 00 00 00 12
# 	指令: pl_set_row_bank      	字节码: 12 00 0d 00
# 	指令: pl_bge               	字节码: 09 14 c7 08
# 	指令: pl_addi              	字节码: 0a 01 07 07
# 	指令: pl_addi              	字节码: 0a 01 0a 0a
# 	指令: pl_addi              	字节码: 0a 01 0b 0b
# 	指令: pl_jump              	字节码: 00 00 00 0e
# 	指令: pl_exit              	字节码: 0b 00 00 00
